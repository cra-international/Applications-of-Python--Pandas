# %% [markdown]
# # Python: Pandas

# %% [markdown]
# In [Python Intro to Python - II](https://github.com/cra-international/Intro-to-Python/tree/master/Intro%20to%20Python%20-%20II), we explore some foundamental functions provided by Pandas module in Python. Feel free to check out comprehensive [Python API Rerence](https://pandas.pydata.org/docs/reference/index.html) to learn more pandas.
#
# We will now dive deeper into the Pandas package, which is an open source library built on top of NumPy. It allows for fast analysis and data cleaning and preparation and has built-in visualization features.

# %% [markdown]
# ![PandasTrend](https://warehouse-camo.ingress.cmh1.psfhosted.org/72a12ce501802d03822c790fa370b2725a40d218/68747470733a2f2f6e7363686c6f652e6769746875622e696f2f737461636b746167732f736f2d6578616d706c652e737667)

# %% [markdown]
# # What's Pandas is for

# %% [markdown]
# Pandas has so many uses that it might make sense to list the things it can't do instead of what it can do.
#
# This tool is essentially your data’s home. Through pandas, you get acquainted with your data by cleaning, transforming, and analyzing it.
#
# For example, say you want to explore a dataset stored in a CSV on your computer. Pandas will extract the data from that CSV into a DataFrame — a table, basically — then let you do things like:
#
# - Calculate statistics and answer questions about the data, like
# - What's the average, median, max, or min of each column?
# - Does column A correlate with column B?
# - What does the distribution of data in column C look like?
# - Clean the data by doing things like removing missing values and filtering rows or columns by some criteria
# - Visualize the data with help from Matplotlib. Plot bars, lines, histograms, bubbles, and more.
# - Store the cleaned, transformed data back into a CSV, other file or database

# %% [markdown]
# # Optional: Intall Pandas

# %% [markdown]
# Open up your terminal program (for Mac users) or command line (for PC users) and install it using either of the following commands:
#
# **conda install pandas**
#
# OR
#
# **pip install pandas**

# %% [markdown]
# Alternatively, if you're currently viewing this article in a Jupyter notebook you can run this cell:

# %%
# !pip install pandas

# %% [markdown]
# _Note:The ! at the beginning runs cells as if they were in a terminal._

# %% [markdown]
# # Import Pandas
# To import pandas we usually import it with a shorter name since it's used so much:

# %%
import pandas as pd

# %%
pd.*?

# %%
pd.DataFrame?

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Sections
# - 1. <a href='#Series'>Series</a>
#
#     - 1.1 <a href='#CreateSeries'>Create a Series using list and dictionary</a>
#
# - 2. <a href='#DataFrame'>DataFrame</a>
#
#     - 2.1 <a href='CreateDataFrame'>Create a dataframe </a>
#
#     - 2.2 <a href='#InputData'>Read in Data</a>
#
#         - 2.2.1 <a href='#CSV'>CSV</a>
#
#         - 2.2.2 <a href='#Excel'>Excel</a>
#
#     - 2.3 <a href='#ViewData'>View Data </a>
#
#     - 2.4 <a href='#SelectandIndexDataFrame'>Grabing data from a dataframe </a>
#
#     - 2.5 <a href='#indexSelection'>Index-based selection </a>
#
#     - 2.6 <a href='#LabelSelection'>Label-based selection </a>
#
#     - 2.7 <a href='#ManipulateIndex'>Manipulating the index</a>
#
#     - 2.8 <a href='#ConditionalSelection'>Conditional Selection</a>
#
#     - 2.9 <a href='#Assign Data'>Assign Data </a>
#
#     - 2.10 <a href='#Duplicates'>Handling duplicates </a>
#
#     - 2.11 <a href='#SummaryFunctions'>Summary Functions </a>
#
#     - 2.12 <a href='#MissingData'>Missing Data</a>
#
#     - 2.13 <a href='#Map'>Map</a>
#
#     - 2.14 <a href='#GroupBy'>Using Group by with a dataframe</a>
#
#     - 2.15 <a href='#Sort'>Sorting</a>
#
# - 3. <a href='#MergeJoinConcat'>Merging, joining and Concatenation</a>
#
#     - 3.1 <a href='#Concatenation'>Concatenation</a>
#
#     - 3.2 <a href='#Merging'>Merging</a>
#
#     - 3.3 <a href='#Joining'>Joining</a>
#
# - 4. <a href='#Pivot'>Pivot Table</a>
#
# - 6. <a href='#Transpose'>Transpose Table</a>
#
# - 7. <a href='#HTML'>Optional: Data input from html</a>
#
# - 8. <a href='#SQL'>Optional: Data input from SQL</a>

# %% [markdown]
# # Series
# <a id='Series'> </a>

# %% [markdown]
# A Series is essentially a _column_. A Series is very similar to a NumPy array (in fact it is built on top of the NumPy array object). What differentiates the NumPy array from a Series, is that a Series can have axis labels, meaning it can be indexed by a label, instead of just a number location. It also doesn't need to hold numeric data, it can hold any arbitrary Python Object but all data in a series has to be same daya type.

# %% [markdown]
# ![Series](https://miro.medium.com/max/700/1*3h2YForpOw5O_MjHgMOBsQ.png)

# %% [markdown]
# ### Creating a Series
# <a id='CreateSeries'> </a>
# You can convert a list,numpy array, or dictionary to a Series:

# %% [markdown]
# _Using List with default index setting_
#
#
# Lists are used to store multiple items in a single variable.

# %%
my_list = [10,20,30]
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# _Using List with specified index_

# %%
labels = ['a','b','c']
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# _Dictionary_
#
# Dictionaries are used to store data values in **key:value** pairs. A dictionary is a collection which is unordered, changeable and does not allow duplicates. Dictionaries are written with curly brackets, and have keys and values. If we create a Series from a python dictionary, the **key becomes the row index while the value becomes the value at that row index.**

# %%
d = {'a':10,'b':20,'c':30}
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# Things don’t change if the values in the dictionary contain a list of items. The list items remain part of a single row index as in the case below

# %%
d = {'a' : [1,2,3], 'b': [4,5], 'c':6, 'd': "Hello World"}
pd.Series(d)
# Out:
# a      [1, 2, 3]
# b         [4, 5]
# c              6
# d    Hello World
# dtype: object

# %% [markdown]
# # DataFrames
# <a id='DataFrame'> </a>
# A DataFrame is a multi-dimensional table made up of a collection of Series. DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index.

# %% [markdown]
# ![df](https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png)

# %% [markdown]
# _Create DataFrames_
#
# <a id='CreateDataFrame'> </a>
#
#
# We are using the pd.DataFrame() constructor to generate these DataFrame objects. The syntax for declaring a new one is a dictionary whose keys are the column names (apples and oranges in this example), and whose values are a list of entries. This is the standard way of constructing a new DataFrame, and the one you are most likely to encounter. The dictionary-list constructor assigns values to the column labels, but just uses an ascending count from 0 (0, 1, 2, 3, ...)

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
pd.DataFrame(data)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# The list of row labels used in a DataFrame is known as an Index. We can assign values to it by using an index parameter in our constructor. Let's customize our index:

# %%
pd.DataFrame(data, index=['Sam', 'Robert', 'Lily', 'David'])
# Out:
#         apples  oranges
# Sam          3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
#Pratice; see if you could create a dataframe looks like the print-out
data = {
    'name': ['nick','david','joe','rosss'], 
    'age': [5,10, 7, 6]
}
pd.DataFrame(data)
# Out:
#     name  age
# 0   nick    5
# 1  david   10
# 2    joe    7
# 3  rosss    6

# %% [markdown]
# # Read in data
# <a id='InputData'> </a>
#
# It’s quite simple to load data from various file formats into a DataFrame.

# %% [markdown]
# ### CSV
# <a id='CSV'> </a>
#
#
# The pd.read_csv() function is well-endowed, with over 30 optional parameters you can specify. For example, you can see in this dataset that the CSV file has a built-in index, which pandas did not pick up on automatically. To make pandas use that column for the index (instead of creating a new one from scratch), we can specify an index_col.
#
#
# This data is from [Kaggle](https://www.kaggle.com/gpreda/covid-world-vaccination-progress) which track COVID-19 vaccination in the world. Data is collected daily from [Our World in Data](https://ourworldindata.org/) GitHub repository for covid-19, merged and uploaded.

# %%
df = pd.read_csv('country_vaccinations.csv')
df
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Argentina      ARG  2020-12-29               700.0                NaN
# 1     Argentina      ARG  2020-12-30                 NaN                NaN
# 2     Argentina      ARG  2020-12-31             32013.0                NaN
# 3     Argentina      ARG  2021-01-01                 NaN                NaN
# 4     Argentina      ARG  2021-01-02                 NaN                NaN
# ...         ...      ...         ...                 ...                ...
# 1392      Wales      NaN  2021-01-18            162197.0           161932.0
# 1393      Wales      NaN  2021-01-19            176186.0           175816.0
# 1394      Wales      NaN  2021-01-20            190831.0           190435.0
# 1395      Wales      NaN  2021-01-21            212732.0           212317.0
# 1396      Wales      NaN  2021-01-22            241016.0           240547.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN             15656.0
# 2                         NaN                     NaN             15656.0
# 3                         NaN                     NaN             11070.0
# 4                         NaN                     NaN              8776.0
# ...                       ...                     ...                 ...
# 1392                    265.0                 10259.0             10123.0
# 1393                    370.0                 13989.0             10672.0
# 1394                    396.0                 14645.0             11105.0
# 1395                    415.0                 21901.0             12318.0
# 1396                    469.0                 28284.0             15148.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                            NaN
# 1                                NaN                            NaN
# 2                               0.07                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 1392                            5.14                           5.14
# 1393                            5.59                           5.58
# 1394                            6.05                           6.04
# 1395                            6.75                           6.73
# 1396                            7.64                           7.63
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                           346.0
# 2                                     NaN                           346.0
# 3                                     NaN                           245.0
# 4                                     NaN                           194.0
# ...                                   ...                             ...
# 1392                                 0.01                          3211.0
# 1393                                 0.01                          3385.0
# 1394                                 0.01                          3522.0
# 1395                                 0.01                          3907.0
# 1396                                 0.01                          4804.0
#
#                                  vaccines                       source_name  \
# 0                               Sputnik V                Ministry of Health
# 1                               Sputnik V                Ministry of Health
# 2                               Sputnik V                Ministry of Health
# 3                               Sputnik V                Ministry of Health
# 4                               Sputnik V                Ministry of Health
# ...                                   ...                               ...
# 1392  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1393  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1394  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1395  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1396  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                 ...
# 1392  https://coronavirus.data.gov.uk/details/health...
# 1393  https://coronavirus.data.gov.uk/details/health...
# 1394  https://coronavirus.data.gov.uk/details/health...
# 1395  https://coronavirus.data.gov.uk/details/health...
# 1396  https://coronavirus.data.gov.uk/details/health...
#
# [1397 rows x 15 columns]

# %% [markdown]
# ### Excel
# <a id='Excel'> </a>
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %%
### Excel Input
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# ### HTML
# <a id='HTML'> </a>
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %%
#Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

list_df = pd.read_html('https://en.wikipedia.org/wiki/Pythonidae')

len(list_df)
# Out:
# 8

# %%
list_df[1]
# Out:
#                                            Pythonidae  \
# 0                                                 NaN
# 1                      Indian python (Python molurus)
# 2                           Scientific classification
# 3                                            Kingdom:
# 4                                             Phylum:
# 5                                              Class:
# 6                                              Order:
# 7                                           Suborder:
# 8                                        Superfamily:
# 9                                             Family:
# 10                                           Synonyms
# 11  Pythonoidia - Fitzinger, 1826 Pythonoidei - Ei...
#
#                                          Pythonidae.1
# 0                                                 NaN
# 1                      Indian python (Python molurus)
# 2                           Scientific classification
# 3                                            Animalia
# 4                                            Chordata
# 5                                            Reptilia
# 6                                            Squamata
# 7                                           Serpentes
# 8                                         Pythonoidea
# 9                           PythonidaeFitzinger, 1826
# 10                                           Synonyms
# 11  Pythonoidia - Fitzinger, 1826 Pythonoidei - Ei...

# %% [markdown]
# **Let use COVID Vaccine data for the following tutorial:**

# %% [markdown]
# ## Viewing data
#
# <a id='ViewData'> </a>
#
# The first thing to do when opening a new dataset is print out a few rows to keep as a visual reference. We accomplish this with .head(). witch outputs the first five rows of your DataFrame by default. for example.:
#
# ![image.png](attachment:image.png)

# %%
df.head()
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0                NaN
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
# 4  Argentina      ARG  2021-01-02                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN             15656.0
# 2                      NaN                     NaN             15656.0
# 3                      NaN                     NaN             11070.0
# 4                      NaN                     NaN              8776.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                            NaN
# 1                             NaN                            NaN
# 2                            0.07                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                           346.0
# 2                                  NaN                           346.0
# 3                                  NaN                           245.0
# 4                                  NaN                           194.0
#
#     vaccines         source_name  \
# 0  Sputnik V  Ministry of Health
# 1  Sputnik V  Ministry of Health
# 2  Sputnik V  Ministry of Health
# 3  Sputnik V  Ministry of Health
# 4  Sputnik V  Ministry of Health
#
#                                       source_website
# 0  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4  http://datos.salud.gob.ar/dataset/vacunas-cont...

# %% [markdown]
# To see the last five rows use .tail(). tail() also accepts a number, and in this case we printing the bottom five rows.:

# %%
df.tail()
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 1392   Wales      NaN  2021-01-18            162197.0           161932.0
# 1393   Wales      NaN  2021-01-19            176186.0           175816.0
# 1394   Wales      NaN  2021-01-20            190831.0           190435.0
# 1395   Wales      NaN  2021-01-21            212732.0           212317.0
# 1396   Wales      NaN  2021-01-22            241016.0           240547.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1392                    265.0                 10259.0             10123.0
# 1393                    370.0                 13989.0             10672.0
# 1394                    396.0                 14645.0             11105.0
# 1395                    415.0                 21901.0             12318.0
# 1396                    469.0                 28284.0             15148.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1392                            5.14                           5.14
# 1393                            5.59                           5.58
# 1394                            6.05                           6.04
# 1395                            6.75                           6.73
# 1396                            7.64                           7.63
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 1392                                 0.01                          3211.0
# 1393                                 0.01                          3385.0
# 1394                                 0.01                          3522.0
# 1395                                 0.01                          3907.0
# 1396                                 0.01                          4804.0
#
#                                  vaccines                       source_name  \
# 1392  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1393  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1394  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1395  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1396  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website
# 1392  https://coronavirus.data.gov.uk/details/health...
# 1393  https://coronavirus.data.gov.uk/details/health...
# 1394  https://coronavirus.data.gov.uk/details/health...
# 1395  https://coronavirus.data.gov.uk/details/health...
# 1396  https://coronavirus.data.gov.uk/details/health...

# %% [markdown]
# To get info about your data..info() should be one of the very first commands you run after loading your data.
#
# .info() provides the essential details about your dataset, such as the number of rows and columns, the number of non-null values, what type of data is in each column, and how much memory your DataFrame is using.
#
# Notice in our dataset we have some obvious missing values in the various columns such as iso_code. We'll look at how to handle those in a bit.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1397 entries, 0 to 1396
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              1397 non-null   object
#  1   iso_code                             1240 non-null   object
#  2   date                                 1397 non-null   object
#  3   total_vaccinations                   919 non-null    float64
#  4   people_vaccinated                    885 non-null    float64
#  5   people_fully_vaccinated              223 non-null    float64
#  6   daily_vaccinations_raw               738 non-null    float64
#  7   daily_vaccinations                   1337 non-null   float64
#  8   total_vaccinations_per_hundred       919 non-null    float64
#  9   people_vaccinated_per_hundred        885 non-null    float64
#  10  people_fully_vaccinated_per_hundred  223 non-null    float64
#  11  daily_vaccinations_per_million       1337 non-null   float64
#  12  vaccines                             1397 non-null   object
#  13  source_name                          1397 non-null   object
#  14  source_website                       1397 non-null   object
# dtypes: float64(9), object(6)
# memory usage: 163.8+ KB

# %%
#Another fast and useful attribute is .shape, which outputs just a tuple of (rows, columns)
df.shape
# Out:
# (1397, 15)

# %% [markdown]
# ## Selection and Indexing
# <a id='SelectandIndexDataFrame'> </a>
#
#
# In Python, we can access the property of an object by accessing it as an attribute. A book object, for example, might have a title property, which we can access by calling book.title. Columns in a pandas DataFrame work in much the same way.
#
# Hence to access the country property of dataframe we can use:

# %%
df.country
# Out:
# 0       Argentina
# 1       Argentina
# 2       Argentina
# 3       Argentina
# 4       Argentina
#           ...
# 1392        Wales
# 1393        Wales
# 1394        Wales
# 1395        Wales
# 1396        Wales
# Name: country, Length: 1397, dtype: object

# %% [markdown]
# Alternatively, we can access its values using the indexing ([]) operator. We can do the same with columns in a DataFrame.
#
#
# indexing operator [] does have the advantage that it can handle column names with reserved characters in them (e.g. if we had a country providence column, df.country providence wouldn't work).

# %%
df['vaccines']
# Out:
# 0                                 Sputnik V
# 1                                 Sputnik V
# 2                                 Sputnik V
# 3                                 Sputnik V
# 4                                 Sputnik V
#                        ...
# 1392    Oxford/AstraZeneca, Pfizer/BioNTech
# 1393    Oxford/AstraZeneca, Pfizer/BioNTech
# 1394    Oxford/AstraZeneca, Pfizer/BioNTech
# 1395    Oxford/AstraZeneca, Pfizer/BioNTech
# 1396    Oxford/AstraZeneca, Pfizer/BioNTech
# Name: vaccines, Length: 1397, dtype: object

# %%
type(df.vaccines)
# Out:
# pandas.core.series.Series

# %%
# Pass a list of column names
df[['country','vaccines']]
# Out:
#         country                             vaccines
# 0     Argentina                            Sputnik V
# 1     Argentina                            Sputnik V
# 2     Argentina                            Sputnik V
# 3     Argentina                            Sputnik V
# 4     Argentina                            Sputnik V
# ...         ...                                  ...
# 1392      Wales  Oxford/AstraZeneca, Pfizer/BioNTech
# 1393      Wales  Oxford/AstraZeneca, Pfizer/BioNTech
# 1394      Wales  Oxford/AstraZeneca, Pfizer/BioNTech
# 1395      Wales  Oxford/AstraZeneca, Pfizer/BioNTech
# 1396      Wales  Oxford/AstraZeneca, Pfizer/BioNTech
#
# [1397 rows x 2 columns]

# %%
# Practice
# see if you can you access the source_name column in the df

# %% [markdown]
# ## Index-based selection
#
# <a id='indexSelection'> </a>
#
# Pandas indexing works in one of two paradigms. The first is index-based selection: selecting data based on its numerical position in the data. **iloc** follows this paradigm.
#
# To select the first row of data in a DataFrame, we may use the following:

# %%
df.iloc[0]
# Out:
# country                                                                        Argentina
# iso_code                                                                             ARG
# date                                                                          2020-12-29
# total_vaccinations                                                                   700
# people_vaccinated                                                                    NaN
# people_fully_vaccinated                                                              NaN
# daily_vaccinations_raw                                                               NaN
# daily_vaccinations                                                                   NaN
# total_vaccinations_per_hundred                                                         0
# people_vaccinated_per_hundred                                                        NaN
# people_fully_vaccinated_per_hundred                                                  NaN
# daily_vaccinations_per_million                                                       NaN
# vaccines                                                                       Sputnik V
# source_name                                                           Ministry of Health
# source_website                         http://datos.salud.gob.ar/dataset/vacunas-cont...
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# iloc is row-first , column-second. On its own, the : operator, which also comes from native Python, means "everything". When combined with other selectors, however, it can be used to indicate a range of values.

# %%
df.iloc[:,0]
# Out:
# 0       Argentina
# 1       Argentina
# 2       Argentina
# 3       Argentina
# 4       Argentina
#           ...
# 1392        Wales
# 1393        Wales
# 1394        Wales
# 1395        Wales
# 1396        Wales
# Name: country, Length: 1397, dtype: object

# %%
#if we want to select the country column from just the first, second, and third row, we would do:
df.iloc[:3,0]
# Out:
# 0    Argentina
# 1    Argentina
# 2    Argentina
# Name: country, dtype: object

# %%
#pratice
#select just the second and third entries, we would do:

# %% [markdown]
# ## Label-based selection
#
# <a id='LabelSelection'> </a>
#
#
# The second paradigm for attribute selection is the one followed by the loc operator: label-based selection. In this paradigm, it's the data index value, not its position, which matters. loc can index more data type: strings, for example. If we have a DataFrame with index values Apples, ..., Potatoes, ..., and we want to select "all the alphabetical fruit choices between Apples and Potatoes", then it's a lot more convenient to index df.loc['Apples':'Potatoes'] than it is to index something like df.loc['Apples', 'Potatoet] (t coming after s in the alphabet).

# %%
# get the first entry in country
df.loc[0, 'country']
# Out:
# 'Argentina'

# %%
df.loc[:, ['country', 'iso_code', 'date']]
# Out:
#         country iso_code        date
# 0     Argentina      ARG  2020-12-29
# 1     Argentina      ARG  2020-12-30
# 2     Argentina      ARG  2020-12-31
# 3     Argentina      ARG  2021-01-01
# 4     Argentina      ARG  2021-01-02
# ...         ...      ...         ...
# 1392      Wales      NaN  2021-01-18
# 1393      Wales      NaN  2021-01-19
# 1394      Wales      NaN  2021-01-20
# 1395      Wales      NaN  2021-01-21
# 1396      Wales      NaN  2021-01-22
#
# [1397 rows x 3 columns]

# %% [markdown]
# ## Manipulating the index
#
# <a id='ManipulateIndex'> </a>
#
# Label-based selection derives its power from the labels in the index. Critically, the index we use is not immutable. We can manipulate the index in any way we see fit.
#
# The set_index() method can be used to do the job.

# %%
df.set_index("date")
# Out:
#               country iso_code  total_vaccinations  people_vaccinated  \
# date
# 2020-12-29  Argentina      ARG               700.0                NaN
# 2020-12-30  Argentina      ARG                 NaN                NaN
# 2020-12-31  Argentina      ARG             32013.0                NaN
# 2021-01-01  Argentina      ARG                 NaN                NaN
# 2021-01-02  Argentina      ARG                 NaN                NaN
# ...               ...      ...                 ...                ...
# 2021-01-18      Wales      NaN            162197.0           161932.0
# 2021-01-19      Wales      NaN            176186.0           175816.0
# 2021-01-20      Wales      NaN            190831.0           190435.0
# 2021-01-21      Wales      NaN            212732.0           212317.0
# 2021-01-22      Wales      NaN            241016.0           240547.0
#
#             people_fully_vaccinated  daily_vaccinations_raw  \
# date
# 2020-12-29                      NaN                     NaN
# 2020-12-30                      NaN                     NaN
# 2020-12-31                      NaN                     NaN
# 2021-01-01                      NaN                     NaN
# 2021-01-02                      NaN                     NaN
# ...                             ...                     ...
# 2021-01-18                    265.0                 10259.0
# 2021-01-19                    370.0                 13989.0
# 2021-01-20                    396.0                 14645.0
# 2021-01-21                    415.0                 21901.0
# 2021-01-22                    469.0                 28284.0
#
#             daily_vaccinations  total_vaccinations_per_hundred  \
# date
# 2020-12-29                 NaN                            0.00
# 2020-12-30             15656.0                             NaN
# 2020-12-31             15656.0                            0.07
# 2021-01-01             11070.0                             NaN
# 2021-01-02              8776.0                             NaN
# ...                        ...                             ...
# 2021-01-18             10123.0                            5.14
# 2021-01-19             10672.0                            5.59
# 2021-01-20             11105.0                            6.05
# 2021-01-21             12318.0                            6.75
# 2021-01-22             15148.0                            7.64
#
#             people_vaccinated_per_hundred  \
# date
# 2020-12-29                            NaN
# 2020-12-30                            NaN
# 2020-12-31                            NaN
# 2021-01-01                            NaN
# 2021-01-02                            NaN
# ...                                   ...
# 2021-01-18                           5.14
# 2021-01-19                           5.58
# 2021-01-20                           6.04
# 2021-01-21                           6.73
# 2021-01-22                           7.63
#
#             people_fully_vaccinated_per_hundred  \
# date
# 2020-12-29                                  NaN
# 2020-12-30                                  NaN
# 2020-12-31                                  NaN
# 2021-01-01                                  NaN
# 2021-01-02                                  NaN
# ...                                         ...
# 2021-01-18                                 0.01
# 2021-01-19                                 0.01
# 2021-01-20                                 0.01
# 2021-01-21                                 0.01
# 2021-01-22                                 0.01
#
#             daily_vaccinations_per_million  \
# date
# 2020-12-29                             NaN
# 2020-12-30                           346.0
# 2020-12-31                           346.0
# 2021-01-01                           245.0
# 2021-01-02                           194.0
# ...                                    ...
# 2021-01-18                          3211.0
# 2021-01-19                          3385.0
# 2021-01-20                          3522.0
# 2021-01-21                          3907.0
# 2021-01-22                          4804.0
#
#                                        vaccines  \
# date
# 2020-12-29                            Sputnik V
# 2020-12-30                            Sputnik V
# 2020-12-31                            Sputnik V
# 2021-01-01                            Sputnik V
# 2021-01-02                            Sputnik V
# ...                                         ...
# 2021-01-18  Oxford/AstraZeneca, Pfizer/BioNTech
# 2021-01-19  Oxford/AstraZeneca, Pfizer/BioNTech
# 2021-01-20  Oxford/AstraZeneca, Pfizer/BioNTech
# 2021-01-21  Oxford/AstraZeneca, Pfizer/BioNTech
# 2021-01-22  Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                  source_name  \
# date
# 2020-12-29                Ministry of Health
# 2020-12-30                Ministry of Health
# 2020-12-31                Ministry of Health
# 2021-01-01                Ministry of Health
# 2021-01-02                Ministry of Health
# ...                                      ...
# 2021-01-18  Government of the United Kingdom
# 2021-01-19  Government of the United Kingdom
# 2021-01-20  Government of the United Kingdom
# 2021-01-21  Government of the United Kingdom
# 2021-01-22  Government of the United Kingdom
#
#                                                source_website
# date
# 2020-12-29  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2020-12-30  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2020-12-31  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2021-01-01  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2021-01-02  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                       ...
# 2021-01-18  https://coronavirus.data.gov.uk/details/health...
# 2021-01-19  https://coronavirus.data.gov.uk/details/health...
# 2021-01-20  https://coronavirus.data.gov.uk/details/health...
# 2021-01-21  https://coronavirus.data.gov.uk/details/health...
# 2021-01-22  https://coronavirus.data.gov.uk/details/health...
#
# [1397 rows x 14 columns]

# %%
#pratice
#use value based selection to look at the vaccine get entered on 2020-12-30

# %% [markdown]
# ### Conditional Selection
# <a id='ConditionalSelection'> </a>
#
# So far we've been indexing various strides of data, using structural properties of the DataFrame itself. To do interesting things with the data, however, we often need to ask questions based on conditions.
#
# Suppose that we're interested specifically in covid-19 vaccines in US.

# %%
#We can start by checking if each vaccine is in US or not:
# This operation produced a Series of True/False booleans based on the country of each record. This result can then be used inside of loc to select the relevant data:

df.country=='United States'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1392    False
# 1393    False
# 1394    False
# 1395    False
# 1396    False
# Name: country, Length: 1397, dtype: bool

# %%
df.loc[df.country=='United States']
# Out:
#             country iso_code        date  total_vaccinations  \
# 1321  United States      USA  2020-12-20            556208.0
# 1322  United States      USA  2020-12-21            614117.0
# 1323  United States      USA  2020-12-22                 NaN
# 1324  United States      USA  2020-12-23           1008025.0
# 1325  United States      USA  2020-12-24                 NaN
# 1326  United States      USA  2020-12-25                 NaN
# 1327  United States      USA  2020-12-26           1944585.0
# 1328  United States      USA  2020-12-27                 NaN
# 1329  United States      USA  2020-12-28           2127143.0
# 1330  United States      USA  2020-12-29                 NaN
# 1331  United States      USA  2020-12-30           2794588.0
# 1332  United States      USA  2020-12-31                 NaN
# 1333  United States      USA  2021-01-01                 NaN
# 1334  United States      USA  2021-01-02           4225756.0
# 1335  United States      USA  2021-01-03                 NaN
# 1336  United States      USA  2021-01-04           4563260.0
# 1337  United States      USA  2021-01-05           4836469.0
# 1338  United States      USA  2021-01-06           5306797.0
# 1339  United States      USA  2021-01-07           5919418.0
# 1340  United States      USA  2021-01-08           6688231.0
# 1341  United States      USA  2021-01-09                 NaN
# 1342  United States      USA  2021-01-10                 NaN
# 1343  United States      USA  2021-01-11           8987322.0
# 1344  United States      USA  2021-01-12           9327138.0
# 1345  United States      USA  2021-01-13          10278462.0
# 1346  United States      USA  2021-01-14          11148991.0
# 1347  United States      USA  2021-01-15          12279180.0
# 1348  United States      USA  2021-01-16                 NaN
# 1349  United States      USA  2021-01-17                 NaN
# 1350  United States      USA  2021-01-18                 NaN
# 1351  United States      USA  2021-01-19          15707588.0
# 1352  United States      USA  2021-01-20          16525281.0
# 1353  United States      USA  2021-01-21          17546374.0
# 1354  United States      USA  2021-01-22          19107959.0
# 1355  United States      USA  2021-01-23          20537990.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1321           556208.0                      NaN                     NaN
# 1322           614117.0                      NaN                 57909.0
# 1323                NaN                      NaN                     NaN
# 1324          1008025.0                      NaN                     NaN
# 1325                NaN                      NaN                     NaN
# 1326                NaN                      NaN                     NaN
# 1327          1944585.0                      NaN                     NaN
# 1328                NaN                      NaN                     NaN
# 1329          2127143.0                      NaN                     NaN
# 1330                NaN                      NaN                     NaN
# 1331          2794588.0                      NaN                     NaN
# 1332                NaN                      NaN                     NaN
# 1333                NaN                      NaN                     NaN
# 1334          4225756.0                      NaN                     NaN
# 1335                NaN                      NaN                     NaN
# 1336          4563260.0                      NaN                     NaN
# 1337          4836469.0                      NaN                273209.0
# 1338          5306797.0                      NaN                470328.0
# 1339          5919418.0                      NaN                612621.0
# 1340          6688231.0                      NaN                768813.0
# 1341                NaN                      NaN                     NaN
# 1342                NaN                      NaN                     NaN
# 1343          8987322.0                      NaN                     NaN
# 1344          9327138.0                      NaN                339816.0
# 1345                NaN                      NaN                951324.0
# 1346          9690757.0                1342086.0                870529.0
# 1347         10595866.0                1610524.0               1130189.0
# 1348                NaN                      NaN                     NaN
# 1349                NaN                      NaN                     NaN
# 1350                NaN                      NaN                     NaN
# 1351         13595803.0                2023124.0                     NaN
# 1352         14270441.0                2161419.0                817693.0
# 1353         15053257.0                2394961.0               1021093.0
# 1354         16243093.0                2756953.0               1561585.0
# 1355         17390345.0                3027865.0               1430031.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 1321                 NaN                            0.17
# 1322             57909.0                            0.19
# 1323            127432.0                             NaN
# 1324            150606.0                            0.30
# 1325            191001.0                             NaN
# 1326            215238.0                             NaN
# 1327            231396.0                            0.59
# 1328            211379.0                             NaN
# 1329            216147.0                            0.64
# 1330            235685.0                             NaN
# 1331            255223.0                            0.84
# 1332            278776.0                             NaN
# 1333            302329.0                             NaN
# 1334            325882.0                            1.28
# 1335            336949.0                             NaN
# 1336            348017.0                            1.38
# 1337            339372.0                            1.46
# 1338            358887.0                            1.60
# 1339            378253.0                            1.79
# 1340            419933.0                            2.02
# 1341            461263.0                             NaN
# 1342            546636.0                             NaN
# 1343            632009.0                            2.72
# 1344            641524.0                            2.82
# 1345            710238.0                            3.11
# 1346            747082.0                            3.37
# 1347            798707.0                            3.71
# 1348            811670.0                             NaN
# 1349            824632.0                             NaN
# 1350            837595.0                             NaN
# 1351            911493.0                            4.75
# 1352            892403.0                            4.99
# 1353            913912.0                            5.30
# 1354            975540.0                            5.77
# 1355           1057387.0                            6.20
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 1321                           0.17                                  NaN
# 1322                           0.19                                  NaN
# 1323                            NaN                                  NaN
# 1324                           0.30                                  NaN
# 1325                            NaN                                  NaN
# 1326                            NaN                                  NaN
# 1327                           0.59                                  NaN
# 1328                            NaN                                  NaN
# 1329                           0.64                                  NaN
# 1330                            NaN                                  NaN
# 1331                           0.84                                  NaN
# 1332                            NaN                                  NaN
# 1333                            NaN                                  NaN
# 1334                           1.28                                  NaN
# 1335                            NaN                                  NaN
# 1336                           1.38                                  NaN
# 1337                           1.46                                  NaN
# 1338                           1.60                                  NaN
# 1339                           1.79                                  NaN
# 1340                           2.02                                  NaN
# 1341                            NaN                                  NaN
# 1342                            NaN                                  NaN
# 1343                           2.72                                  NaN
# 1344                           2.82                                  NaN
# 1345                            NaN                                  NaN
# 1346                           2.93                                 0.41
# 1347                           3.20                                 0.49
# 1348                            NaN                                  NaN
# 1349                            NaN                                  NaN
# 1350                            NaN                                  NaN
# 1351                           4.11                                 0.61
# 1352                           4.31                                 0.65
# 1353                           4.55                                 0.72
# 1354                           4.91                                 0.83
# 1355                           5.25                                 0.91
#
#       daily_vaccinations_per_million                  vaccines  \
# 1321                             NaN  Moderna, Pfizer/BioNTech
# 1322                           175.0  Moderna, Pfizer/BioNTech
# 1323                           385.0  Moderna, Pfizer/BioNTech
# 1324                           455.0  Moderna, Pfizer/BioNTech
# 1325                           577.0  Moderna, Pfizer/BioNTech
# 1326                           650.0  Moderna, Pfizer/BioNTech
# 1327                           699.0  Moderna, Pfizer/BioNTech
# 1328                           639.0  Moderna, Pfizer/BioNTech
# 1329                           653.0  Moderna, Pfizer/BioNTech
# 1330                           712.0  Moderna, Pfizer/BioNTech
# 1331                           771.0  Moderna, Pfizer/BioNTech
# 1332                           842.0  Moderna, Pfizer/BioNTech
# 1333                           913.0  Moderna, Pfizer/BioNTech
# 1334                           985.0  Moderna, Pfizer/BioNTech
# 1335                          1018.0  Moderna, Pfizer/BioNTech
# 1336                          1051.0  Moderna, Pfizer/BioNTech
# 1337                          1025.0  Moderna, Pfizer/BioNTech
# 1338                          1084.0  Moderna, Pfizer/BioNTech
# 1339                          1143.0  Moderna, Pfizer/BioNTech
# 1340                          1269.0  Moderna, Pfizer/BioNTech
# 1341                          1394.0  Moderna, Pfizer/BioNTech
# 1342                          1651.0  Moderna, Pfizer/BioNTech
# 1343                          1909.0  Moderna, Pfizer/BioNTech
# 1344                          1938.0  Moderna, Pfizer/BioNTech
# 1345                          2146.0  Moderna, Pfizer/BioNTech
# 1346                          2257.0  Moderna, Pfizer/BioNTech
# 1347                          2413.0  Moderna, Pfizer/BioNTech
# 1348                          2452.0  Moderna, Pfizer/BioNTech
# 1349                          2491.0  Moderna, Pfizer/BioNTech
# 1350                          2530.0  Moderna, Pfizer/BioNTech
# 1351                          2754.0  Moderna, Pfizer/BioNTech
# 1352                          2696.0  Moderna, Pfizer/BioNTech
# 1353                          2761.0  Moderna, Pfizer/BioNTech
# 1354                          2947.0  Moderna, Pfizer/BioNTech
# 1355                          3194.0  Moderna, Pfizer/BioNTech
#
#                                      source_name  \
# 1321  Centers for Disease Control and Prevention
# 1322  Centers for Disease Control and Prevention
# 1323  Centers for Disease Control and Prevention
# 1324  Centers for Disease Control and Prevention
# 1325  Centers for Disease Control and Prevention
# 1326  Centers for Disease Control and Prevention
# 1327  Centers for Disease Control and Prevention
# 1328  Centers for Disease Control and Prevention
# 1329  Centers for Disease Control and Prevention
# 1330  Centers for Disease Control and Prevention
# 1331  Centers for Disease Control and Prevention
# 1332  Centers for Disease Control and Prevention
# 1333  Centers for Disease Control and Prevention
# 1334  Centers for Disease Control and Prevention
# 1335  Centers for Disease Control and Prevention
# 1336  Centers for Disease Control and Prevention
# 1337  Centers for Disease Control and Prevention
# 1338  Centers for Disease Control and Prevention
# 1339  Centers for Disease Control and Prevention
# 1340  Centers for Disease Control and Prevention
# 1341  Centers for Disease Control and Prevention
# 1342  Centers for Disease Control and Prevention
# 1343  Centers for Disease Control and Prevention
# 1344  Centers for Disease Control and Prevention
# 1345  Centers for Disease Control and Prevention
# 1346  Centers for Disease Control and Prevention
# 1347  Centers for Disease Control and Prevention
# 1348  Centers for Disease Control and Prevention
# 1349  Centers for Disease Control and Prevention
# 1350  Centers for Disease Control and Prevention
# 1351  Centers for Disease Control and Prevention
# 1352  Centers for Disease Control and Prevention
# 1353  Centers for Disease Control and Prevention
# 1354  Centers for Disease Control and Prevention
# 1355  Centers for Disease Control and Prevention
#
#                                          source_website
# 1321  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1322  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1323  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1324  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1325  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1326  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1327  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1328  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1329  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1330  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1331  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1332  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1333  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1334  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1335  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1336  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1337  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1338  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1339  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1340  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1341  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1342  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1343  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1344  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1345  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1346  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1347  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1348  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1349  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1350  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1351  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1352  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1353  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1354  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1355  https://covid.cdc.gov/covid-data-tracker/#vacc...

# %%
#practiec
#how many records are from UK?

# %% [markdown]
# ### Multiple Conditions
#
# We also wanted to know which records are after 2021-01-01 in UK. We can use the ampersand (&) to bring the two conditions together:

# %%
df.loc[(df.country=='United States')&(df.date>'2021-01-01')]
# Out:
#             country iso_code        date  total_vaccinations  \
# 1334  United States      USA  2021-01-02           4225756.0
# 1335  United States      USA  2021-01-03                 NaN
# 1336  United States      USA  2021-01-04           4563260.0
# 1337  United States      USA  2021-01-05           4836469.0
# 1338  United States      USA  2021-01-06           5306797.0
# 1339  United States      USA  2021-01-07           5919418.0
# 1340  United States      USA  2021-01-08           6688231.0
# 1341  United States      USA  2021-01-09                 NaN
# 1342  United States      USA  2021-01-10                 NaN
# 1343  United States      USA  2021-01-11           8987322.0
# 1344  United States      USA  2021-01-12           9327138.0
# 1345  United States      USA  2021-01-13          10278462.0
# 1346  United States      USA  2021-01-14          11148991.0
# 1347  United States      USA  2021-01-15          12279180.0
# 1348  United States      USA  2021-01-16                 NaN
# 1349  United States      USA  2021-01-17                 NaN
# 1350  United States      USA  2021-01-18                 NaN
# 1351  United States      USA  2021-01-19          15707588.0
# 1352  United States      USA  2021-01-20          16525281.0
# 1353  United States      USA  2021-01-21          17546374.0
# 1354  United States      USA  2021-01-22          19107959.0
# 1355  United States      USA  2021-01-23          20537990.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1334          4225756.0                      NaN                     NaN
# 1335                NaN                      NaN                     NaN
# 1336          4563260.0                      NaN                     NaN
# 1337          4836469.0                      NaN                273209.0
# 1338          5306797.0                      NaN                470328.0
# 1339          5919418.0                      NaN                612621.0
# 1340          6688231.0                      NaN                768813.0
# 1341                NaN                      NaN                     NaN
# 1342                NaN                      NaN                     NaN
# 1343          8987322.0                      NaN                     NaN
# 1344          9327138.0                      NaN                339816.0
# 1345                NaN                      NaN                951324.0
# 1346          9690757.0                1342086.0                870529.0
# 1347         10595866.0                1610524.0               1130189.0
# 1348                NaN                      NaN                     NaN
# 1349                NaN                      NaN                     NaN
# 1350                NaN                      NaN                     NaN
# 1351         13595803.0                2023124.0                     NaN
# 1352         14270441.0                2161419.0                817693.0
# 1353         15053257.0                2394961.0               1021093.0
# 1354         16243093.0                2756953.0               1561585.0
# 1355         17390345.0                3027865.0               1430031.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 1334            325882.0                            1.28
# 1335            336949.0                             NaN
# 1336            348017.0                            1.38
# 1337            339372.0                            1.46
# 1338            358887.0                            1.60
# 1339            378253.0                            1.79
# 1340            419933.0                            2.02
# 1341            461263.0                             NaN
# 1342            546636.0                             NaN
# 1343            632009.0                            2.72
# 1344            641524.0                            2.82
# 1345            710238.0                            3.11
# 1346            747082.0                            3.37
# 1347            798707.0                            3.71
# 1348            811670.0                             NaN
# 1349            824632.0                             NaN
# 1350            837595.0                             NaN
# 1351            911493.0                            4.75
# 1352            892403.0                            4.99
# 1353            913912.0                            5.30
# 1354            975540.0                            5.77
# 1355           1057387.0                            6.20
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 1334                           1.28                                  NaN
# 1335                            NaN                                  NaN
# 1336                           1.38                                  NaN
# 1337                           1.46                                  NaN
# 1338                           1.60                                  NaN
# 1339                           1.79                                  NaN
# 1340                           2.02                                  NaN
# 1341                            NaN                                  NaN
# 1342                            NaN                                  NaN
# 1343                           2.72                                  NaN
# 1344                           2.82                                  NaN
# 1345                            NaN                                  NaN
# 1346                           2.93                                 0.41
# 1347                           3.20                                 0.49
# 1348                            NaN                                  NaN
# 1349                            NaN                                  NaN
# 1350                            NaN                                  NaN
# 1351                           4.11                                 0.61
# 1352                           4.31                                 0.65
# 1353                           4.55                                 0.72
# 1354                           4.91                                 0.83
# 1355                           5.25                                 0.91
#
#       daily_vaccinations_per_million                  vaccines  \
# 1334                           985.0  Moderna, Pfizer/BioNTech
# 1335                          1018.0  Moderna, Pfizer/BioNTech
# 1336                          1051.0  Moderna, Pfizer/BioNTech
# 1337                          1025.0  Moderna, Pfizer/BioNTech
# 1338                          1084.0  Moderna, Pfizer/BioNTech
# 1339                          1143.0  Moderna, Pfizer/BioNTech
# 1340                          1269.0  Moderna, Pfizer/BioNTech
# 1341                          1394.0  Moderna, Pfizer/BioNTech
# 1342                          1651.0  Moderna, Pfizer/BioNTech
# 1343                          1909.0  Moderna, Pfizer/BioNTech
# 1344                          1938.0  Moderna, Pfizer/BioNTech
# 1345                          2146.0  Moderna, Pfizer/BioNTech
# 1346                          2257.0  Moderna, Pfizer/BioNTech
# 1347                          2413.0  Moderna, Pfizer/BioNTech
# 1348                          2452.0  Moderna, Pfizer/BioNTech
# 1349                          2491.0  Moderna, Pfizer/BioNTech
# 1350                          2530.0  Moderna, Pfizer/BioNTech
# 1351                          2754.0  Moderna, Pfizer/BioNTech
# 1352                          2696.0  Moderna, Pfizer/BioNTech
# 1353                          2761.0  Moderna, Pfizer/BioNTech
# 1354                          2947.0  Moderna, Pfizer/BioNTech
# 1355                          3194.0  Moderna, Pfizer/BioNTech
#
#                                      source_name  \
# 1334  Centers for Disease Control and Prevention
# 1335  Centers for Disease Control and Prevention
# 1336  Centers for Disease Control and Prevention
# 1337  Centers for Disease Control and Prevention
# 1338  Centers for Disease Control and Prevention
# 1339  Centers for Disease Control and Prevention
# 1340  Centers for Disease Control and Prevention
# 1341  Centers for Disease Control and Prevention
# 1342  Centers for Disease Control and Prevention
# 1343  Centers for Disease Control and Prevention
# 1344  Centers for Disease Control and Prevention
# 1345  Centers for Disease Control and Prevention
# 1346  Centers for Disease Control and Prevention
# 1347  Centers for Disease Control and Prevention
# 1348  Centers for Disease Control and Prevention
# 1349  Centers for Disease Control and Prevention
# 1350  Centers for Disease Control and Prevention
# 1351  Centers for Disease Control and Prevention
# 1352  Centers for Disease Control and Prevention
# 1353  Centers for Disease Control and Prevention
# 1354  Centers for Disease Control and Prevention
# 1355  Centers for Disease Control and Prevention
#
#                                          source_website
# 1334  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1335  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1336  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1337  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1338  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1339  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1340  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1341  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1342  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1343  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1344  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1345  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1346  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1347  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1348  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1349  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1350  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1351  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1352  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1353  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1354  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1355  https://covid.cdc.gov/covid-data-tracker/#vacc...

# %% [markdown]
# Suppose we are interested in any vaccine info in Argentina or in UK. For this we use a pipe (|):

# %%
df.loc[(df.country=='United States')|(df.country=='Argentina')]
# Out:
#             country iso_code        date  total_vaccinations  \
# 0         Argentina      ARG  2020-12-29               700.0
# 1         Argentina      ARG  2020-12-30                 NaN
# 2         Argentina      ARG  2020-12-31             32013.0
# 3         Argentina      ARG  2021-01-01                 NaN
# 4         Argentina      ARG  2021-01-02                 NaN
# ...             ...      ...         ...                 ...
# 1351  United States      USA  2021-01-19          15707588.0
# 1352  United States      USA  2021-01-20          16525281.0
# 1353  United States      USA  2021-01-21          17546374.0
# 1354  United States      USA  2021-01-22          19107959.0
# 1355  United States      USA  2021-01-23          20537990.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                   NaN                      NaN                     NaN
# 1                   NaN                      NaN                     NaN
# 2                   NaN                      NaN                     NaN
# 3                   NaN                      NaN                     NaN
# 4                   NaN                      NaN                     NaN
# ...                 ...                      ...                     ...
# 1351         13595803.0                2023124.0                     NaN
# 1352         14270441.0                2161419.0                817693.0
# 1353         15053257.0                2394961.0               1021093.0
# 1354         16243093.0                2756953.0               1561585.0
# 1355         17390345.0                3027865.0               1430031.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 0                    NaN                            0.00
# 1                15656.0                             NaN
# 2                15656.0                            0.07
# 3                11070.0                             NaN
# 4                 8776.0                             NaN
# ...                  ...                             ...
# 1351            911493.0                            4.75
# 1352            892403.0                            4.99
# 1353            913912.0                            5.30
# 1354            975540.0                            5.77
# 1355           1057387.0                            6.20
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# ...                             ...                                  ...
# 1351                           4.11                                 0.61
# 1352                           4.31                                 0.65
# 1353                           4.55                                 0.72
# 1354                           4.91                                 0.83
# 1355                           5.25                                 0.91
#
#       daily_vaccinations_per_million                  vaccines  \
# 0                                NaN                 Sputnik V
# 1                              346.0                 Sputnik V
# 2                              346.0                 Sputnik V
# 3                              245.0                 Sputnik V
# 4                              194.0                 Sputnik V
# ...                              ...                       ...
# 1351                          2754.0  Moderna, Pfizer/BioNTech
# 1352                          2696.0  Moderna, Pfizer/BioNTech
# 1353                          2761.0  Moderna, Pfizer/BioNTech
# 1354                          2947.0  Moderna, Pfizer/BioNTech
# 1355                          3194.0  Moderna, Pfizer/BioNTech
#
#                                      source_name  \
# 0                             Ministry of Health
# 1                             Ministry of Health
# 2                             Ministry of Health
# 3                             Ministry of Health
# 4                             Ministry of Health
# ...                                          ...
# 1351  Centers for Disease Control and Prevention
# 1352  Centers for Disease Control and Prevention
# 1353  Centers for Disease Control and Prevention
# 1354  Centers for Disease Control and Prevention
# 1355  Centers for Disease Control and Prevention
#
#                                          source_website
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                 ...
# 1351  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1352  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1353  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1354  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1355  https://covid.cdc.gov/covid-data-tracker/#vacc...
#
# [61 rows x 15 columns]

# %% [markdown]
# Pandas comes with a few built-in conditional selectors, two of which we will highlight here.
#
# The first is isin. isin is lets you select data whose value "is in" a list of values. so we can rewrite above code to:

# %%
df.loc[df.country.isin(['United States','Argentina'])]
# Out:
#             country iso_code        date  total_vaccinations  \
# 0         Argentina      ARG  2020-12-29               700.0
# 1         Argentina      ARG  2020-12-30                 NaN
# 2         Argentina      ARG  2020-12-31             32013.0
# 3         Argentina      ARG  2021-01-01                 NaN
# 4         Argentina      ARG  2021-01-02                 NaN
# ...             ...      ...         ...                 ...
# 1351  United States      USA  2021-01-19          15707588.0
# 1352  United States      USA  2021-01-20          16525281.0
# 1353  United States      USA  2021-01-21          17546374.0
# 1354  United States      USA  2021-01-22          19107959.0
# 1355  United States      USA  2021-01-23          20537990.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                   NaN                      NaN                     NaN
# 1                   NaN                      NaN                     NaN
# 2                   NaN                      NaN                     NaN
# 3                   NaN                      NaN                     NaN
# 4                   NaN                      NaN                     NaN
# ...                 ...                      ...                     ...
# 1351         13595803.0                2023124.0                     NaN
# 1352         14270441.0                2161419.0                817693.0
# 1353         15053257.0                2394961.0               1021093.0
# 1354         16243093.0                2756953.0               1561585.0
# 1355         17390345.0                3027865.0               1430031.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 0                    NaN                            0.00
# 1                15656.0                             NaN
# 2                15656.0                            0.07
# 3                11070.0                             NaN
# 4                 8776.0                             NaN
# ...                  ...                             ...
# 1351            911493.0                            4.75
# 1352            892403.0                            4.99
# 1353            913912.0                            5.30
# 1354            975540.0                            5.77
# 1355           1057387.0                            6.20
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# ...                             ...                                  ...
# 1351                           4.11                                 0.61
# 1352                           4.31                                 0.65
# 1353                           4.55                                 0.72
# 1354                           4.91                                 0.83
# 1355                           5.25                                 0.91
#
#       daily_vaccinations_per_million                  vaccines  \
# 0                                NaN                 Sputnik V
# 1                              346.0                 Sputnik V
# 2                              346.0                 Sputnik V
# 3                              245.0                 Sputnik V
# 4                              194.0                 Sputnik V
# ...                              ...                       ...
# 1351                          2754.0  Moderna, Pfizer/BioNTech
# 1352                          2696.0  Moderna, Pfizer/BioNTech
# 1353                          2761.0  Moderna, Pfizer/BioNTech
# 1354                          2947.0  Moderna, Pfizer/BioNTech
# 1355                          3194.0  Moderna, Pfizer/BioNTech
#
#                                      source_name  \
# 0                             Ministry of Health
# 1                             Ministry of Health
# 2                             Ministry of Health
# 3                             Ministry of Health
# 4                             Ministry of Health
# ...                                          ...
# 1351  Centers for Disease Control and Prevention
# 1352  Centers for Disease Control and Prevention
# 1353  Centers for Disease Control and Prevention
# 1354  Centers for Disease Control and Prevention
# 1355  Centers for Disease Control and Prevention
#
#                                          source_website
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                 ...
# 1351  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1352  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1353  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1354  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1355  https://covid.cdc.gov/covid-data-tracker/#vacc...
#
# [61 rows x 15 columns]

# %%
#practiec
#how many records that have total_vaccinations greater than 300000 in USA or UK

# %% [markdown]
# ## Assign Data
#
# <a id='AssignData'> </a>
#
# Going the other way, assigning data to a DataFrame is easy. You can assign either a constant value:

# %%
df['DownloadFrom'] = 'Kaggle'

# %%
df.head(1)
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
#
#     vaccines         source_name  \
# 0  Sputnik V  Ministry of Health
#
#                                       source_website DownloadFrom
# 0  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle

# %%
#Practice
# use loc to create a USA_Flag column that has value of 1 to where country is USA

# %%
df.loc[df.country=='United States','USA_Flag']=1

# %%
df.loc[df.country=='United States'].USA_Flag
# Out:
# 1321    1.0
# 1322    1.0
# 1323    1.0
# 1324    1.0
# 1325    1.0
# 1326    1.0
# 1327    1.0
# 1328    1.0
# 1329    1.0
# 1330    1.0
# 1331    1.0
# 1332    1.0
# 1333    1.0
# 1334    1.0
# 1335    1.0
# 1336    1.0
# 1337    1.0
# 1338    1.0
# 1339    1.0
# 1340    1.0
# 1341    1.0
# 1342    1.0
# 1343    1.0
# 1344    1.0
# 1345    1.0
# 1346    1.0
# 1347    1.0
# 1348    1.0
# 1349    1.0
# 1350    1.0
# 1351    1.0
# 1352    1.0
# 1353    1.0
# 1354    1.0
# 1355    1.0
# Name: USA_Flag, dtype: float64

# %%
df.loc[df.country=='United Kingdom'].USA_Flag
# Out:
# 1287   NaN
# 1288   NaN
# 1289   NaN
# 1290   NaN
# 1291   NaN
# 1292   NaN
# 1293   NaN
# 1294   NaN
# 1295   NaN
# 1296   NaN
# 1297   NaN
# 1298   NaN
# 1299   NaN
# 1300   NaN
# 1301   NaN
# 1302   NaN
# 1303   NaN
# 1304   NaN
# 1305   NaN
# 1306   NaN
# 1307   NaN
# 1308   NaN
# 1309   NaN
# 1310   NaN
# 1311   NaN
# 1312   NaN
# 1313   NaN
# 1314   NaN
# 1315   NaN
# 1316   NaN
# 1317   NaN
# 1318   NaN
# 1319   NaN
# 1320   NaN
# Name: USA_Flag, dtype: float64

# %% [markdown]
# ## Handling duplicates
#
# <a id='Duplicates'> </a>
#
# To check if there are duplicates rows we can use .drop_duplicates() function wich will also return a copy of our data frame with duplicates removed.

# %%
df.drop_duplicates().shape,df.shape
# Out:
# ((1397, 17), (1397, 17))

# %%
# This dataset does not have duplicate rows, but it is always important to verify you aren't aggregating duplicate rows.
# let's see if there are duplicated rows based on country and iso_code
df.drop_duplicates(subset=['country','iso_code']).shape,df.shape
# Out:
# ((60, 17), (1397, 17))

# %%
df.drop_duplicates(subset=['country','iso_code'])
# Out:
#                    country iso_code        date  total_vaccinations  \
# 0                Argentina      ARG  2020-12-29               700.0
# 26                 Austria      AUT  2021-01-05              8360.0
# 45                 Bahrain      BHR  2020-12-23             38965.0
# 74                 Belgium      BEL  2020-12-28               298.0
# 100                 Brazil      BRA  2021-01-16                 0.0
# 108               Bulgaria      BGR  2020-12-29              1719.0
# 134                 Canada      CAN  2020-12-14               297.0
# 175                  Chile      CHL  2020-12-24               420.0
# 205                  China      CHN  2020-12-15           1500000.0
# 242             Costa Rica      CRI  2020-12-24                55.0
# 268                Croatia      HRV  2020-12-30              7864.0
# 292                 Cyprus      CYP  2021-01-06              3901.0
# 309                Czechia      CZE  2020-12-27              1246.0
# 337                Denmark      DNK  2020-12-27              6588.0
# 365                Ecuador      ECU  2021-01-21                 0.0
# 367                England      NaN  2020-12-20            568044.0
# 401                Estonia      EST  2020-12-28               207.0
# 428                Finland      FIN  2020-12-31              1767.0
# 451                 France      FRA  2021-01-04              1000.0
# 471                Germany      DEU  2020-12-27             24256.0
# 498              Gibraltar      GIB  2021-01-10               420.0
# 511                 Greece      GRC  2020-12-28               386.0
# 538                Hungary      HUN  2020-12-28              1094.0
# 564                Iceland      ISL  2020-12-30              4875.0
# 588                  India      IND  2021-01-15                 0.0
# 597              Indonesia      IDN  2021-01-12                 0.0
# 608                Ireland      IRL  2020-12-31              1800.0
# 629            Isle of Man      IMN  2021-01-21              3558.0
# 631                 Israel      ISR  2020-12-19                57.0
# 667                  Italy      ITA  2020-12-27              6983.0
# 695                 Kuwait      KWT  2020-12-28              2500.0
# 696                 Latvia      LVA  2020-12-28               597.0
# 723              Lithuania      LTU  2020-12-25                 1.0
# 753             Luxembourg      LUX  2020-12-30              1200.0
# 776                  Malta      MLT  2020-12-28               130.0
# 802                 Mexico      MEX  2020-12-24              2924.0
# 833            Netherlands      NLD  2021-01-06              6000.0
# 850       Northern Ireland      NaN  2020-12-13              3623.0
# 891                 Norway      NOR  2020-12-27                 5.0
# 917                   Oman      OMN  2020-12-28              1717.0
# 940                 Panama      PAN  2021-01-19                 0.0
# 945                 Poland      POL  2020-12-28              2000.0
# 971               Portugal      PRT  2020-12-28              4828.0
# 998                Romania      ROU  2020-12-28              2066.0
# 1025                Russia      RUS  2020-12-15             28500.0
# 1055          Saudi Arabia      SAU  2021-01-06            100000.0
# 1067              Scotland      NaN  2020-12-13             18858.0
# 1108                Serbia      SRB  2021-01-08              7000.0
# 1124            Seychelles      SYC  2021-01-09                 0.0
# 1136             Singapore      SGP  2021-01-11              3400.0
# 1148              Slovakia      SVK  2021-01-04                 0.0
# 1166              Slovenia      SVN  2021-01-03              5934.0
# 1186                 Spain      ESP  2021-01-04             82834.0
# 1205                Sweden      SWE  2020-12-27              4115.0
# 1227           Switzerland      CHE  2020-12-23                 0.0
# 1257                Turkey      TUR  2021-01-13                 0.0
# 1268  United Arab Emirates      ARE  2021-01-05            826301.0
# 1287        United Kingdom      GBR  2020-12-20            667287.0
# 1321         United States      USA  2020-12-20            556208.0
# 1356                 Wales      NaN  2020-12-13              8181.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                   NaN                      NaN                     NaN
# 26               8360.0                      NaN                     NaN
# 45              38965.0                      NaN                     NaN
# 74                298.0                      NaN                     NaN
# 100                 0.0                      NaN                     NaN
# 108              1719.0                      NaN                     NaN
# 134               297.0                      NaN                     NaN
# 175               420.0                      NaN                     NaN
# 205           1500000.0                      NaN                     NaN
# 242                 NaN                      NaN                     NaN
# 268              7864.0                      NaN                     NaN
# 292                 NaN                      NaN                     NaN
# 309              1246.0                      NaN                     NaN
# 337              6588.0                      NaN                     NaN
# 365                 0.0                      NaN                     NaN
# 367            568044.0                      NaN                     NaN
# 401               207.0                      NaN                     NaN
# 428              1767.0                      NaN                     NaN
# 451              1000.0                      NaN                     NaN
# 471             24256.0                      NaN                     NaN
# 498               420.0                      NaN                     NaN
# 511               386.0                      NaN                     NaN
# 538                 NaN                      NaN                     NaN
# 564              4875.0                      NaN                     NaN
# 588                 0.0                      NaN                     NaN
# 597                 0.0                      NaN                     NaN
# 608              1800.0                      NaN                     NaN
# 629              3558.0                      NaN                     NaN
# 631                57.0                      NaN                     NaN
# 667              6983.0                      NaN                     NaN
# 695              2500.0                      NaN                     NaN
# 696               597.0                      NaN                     NaN
# 723                 1.0                      NaN                     NaN
# 753              1200.0                      NaN                     NaN
# 776               130.0                      NaN                     NaN
# 802              2924.0                      NaN                     NaN
# 833              6000.0                      NaN                     NaN
# 850              3623.0                      NaN                     NaN
# 891                 5.0                      NaN                     NaN
# 917              1717.0                      NaN                     NaN
# 940                 0.0                      NaN                     NaN
# 945              2000.0                      NaN                     NaN
# 971              4828.0                      NaN                     NaN
# 998              2066.0                      NaN                     NaN
# 1025            28500.0                      NaN                     NaN
# 1055           100000.0                      NaN                     NaN
# 1067            18858.0                      NaN                     NaN
# 1108             7000.0                      NaN                     NaN
# 1124                0.0                      NaN                     NaN
# 1136             3400.0                      NaN                     NaN
# 1148                0.0                      NaN                     NaN
# 1166             5934.0                      NaN                     NaN
# 1186            82834.0                      NaN                     NaN
# 1205             4115.0                      NaN                     NaN
# 1227                0.0                      NaN                     NaN
# 1257                0.0                      NaN                     NaN
# 1268                NaN                      NaN                     NaN
# 1287           667287.0                      NaN                     NaN
# 1321           556208.0                      NaN                     NaN
# 1356             8181.0                      NaN                     NaN
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 0                    NaN                            0.00
# 26                   NaN                            0.09
# 45                   NaN                            2.29
# 74                   NaN                            0.00
# 100                  NaN                            0.00
# 108                  NaN                            0.02
# 134                  NaN                            0.00
# 175                  NaN                            0.00
# 205                  NaN                            0.10
# 242                  NaN                            0.00
# 268                  NaN                            0.19
# 292                  NaN                            0.45
# 309                  NaN                            0.01
# 337                  NaN                            0.11
# 365                  NaN                            0.00
# 367                  NaN                            1.01
# 401                  NaN                            0.02
# 428                  NaN                            0.03
# 451                  NaN                            0.00
# 471                  NaN                            0.03
# 498                  NaN                            1.25
# 511                  NaN                            0.00
# 538                  NaN                            0.01
# 564                  NaN                            1.43
# 588                  NaN                            0.00
# 597                  NaN                            0.00
# 608                  NaN                            0.04
# 629                  NaN                            4.18
# 631                  NaN                            0.00
# 667                  NaN                            0.01
# 695                  NaN                            0.06
# 696                  NaN                            0.03
# 723                  NaN                            0.00
# 753                  NaN                            0.19
# 776                  NaN                            0.03
# 802                  NaN                            0.00
# 833                  NaN                            0.04
# 850                  NaN                            0.19
# 891                  NaN                            0.00
# 917                  NaN                            0.03
# 940                  NaN                            0.00
# 945                  NaN                            0.01
# 971                  NaN                            0.05
# 998                  NaN                            0.01
# 1025                 NaN                            0.02
# 1055                 NaN                            0.29
# 1067                 NaN                            0.35
# 1108                 NaN                            0.10
# 1124                 NaN                            0.00
# 1136                 NaN                            0.06
# 1148                 NaN                            0.00
# 1166                 NaN                            0.29
# 1186                 NaN                            0.18
# 1205                 NaN                            0.04
# 1227                 NaN                            0.00
# 1257                 NaN                            0.00
# 1268                 NaN                            8.35
# 1287                 NaN                            0.98
# 1321                 NaN                            0.17
# 1356                 NaN                            0.26
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               NaN                                  NaN
# 26                             0.09                                  NaN
# 45                             2.29                                  NaN
# 74                             0.00                                  NaN
# 100                            0.00                                  NaN
# 108                            0.02                                  NaN
# 134                            0.00                                  NaN
# 175                            0.00                                  NaN
# 205                            0.10                                  NaN
# 242                             NaN                                  NaN
# 268                            0.19                                  NaN
# 292                             NaN                                  NaN
# 309                            0.01                                  NaN
# 337                            0.11                                  NaN
# 365                            0.00                                  NaN
# 367                            1.01                                  NaN
# 401                            0.02                                  NaN
# 428                            0.03                                  NaN
# 451                            0.00                                  NaN
# 471                            0.03                                  NaN
# 498                            1.25                                  NaN
# 511                            0.00                                  NaN
# 538                             NaN                                  NaN
# 564                            1.43                                  NaN
# 588                            0.00                                  NaN
# 597                            0.00                                  NaN
# 608                            0.04                                  NaN
# 629                            4.18                                  NaN
# 631                            0.00                                  NaN
# 667                            0.01                                  NaN
# 695                            0.06                                  NaN
# 696                            0.03                                  NaN
# 723                            0.00                                  NaN
# 753                            0.19                                  NaN
# 776                            0.03                                  NaN
# 802                            0.00                                  NaN
# 833                            0.04                                  NaN
# 850                            0.19                                  NaN
# 891                            0.00                                  NaN
# 917                            0.03                                  NaN
# 940                            0.00                                  NaN
# 945                            0.01                                  NaN
# 971                            0.05                                  NaN
# 998                            0.01                                  NaN
# 1025                           0.02                                  NaN
# 1055                           0.29                                  NaN
# 1067                           0.35                                  NaN
# 1108                           0.10                                  NaN
# 1124                           0.00                                  NaN
# 1136                           0.06                                  NaN
# 1148                           0.00                                  NaN
# 1166                           0.29                                  NaN
# 1186                           0.18                                  NaN
# 1205                           0.04                                  NaN
# 1227                           0.00                                  NaN
# 1257                           0.00                                  NaN
# 1268                            NaN                                  NaN
# 1287                           0.98                                  NaN
# 1321                           0.17                                  NaN
# 1356                           0.26                                  NaN
#
#       daily_vaccinations_per_million                             vaccines  \
# 0                                NaN                            Sputnik V
# 26                               NaN                      Pfizer/BioNTech
# 45                               NaN           Pfizer/BioNTech, Sinopharm
# 74                               NaN                      Pfizer/BioNTech
# 100                              NaN                              Sinovac
# 108                              NaN             Moderna, Pfizer/BioNTech
# 134                              NaN             Moderna, Pfizer/BioNTech
# 175                              NaN                      Pfizer/BioNTech
# 205                              NaN                        CNBG, Sinovac
# 242                              NaN                      Pfizer/BioNTech
# 268                              NaN                      Pfizer/BioNTech
# 292                              NaN                      Pfizer/BioNTech
# 309                              NaN             Moderna, Pfizer/BioNTech
# 337                              NaN             Moderna, Pfizer/BioNTech
# 365                              NaN                      Pfizer/BioNTech
# 367                              NaN  Oxford/AstraZeneca, Pfizer/BioNTech
# 401                              NaN                      Pfizer/BioNTech
# 428                              NaN                      Pfizer/BioNTech
# 451                              NaN                      Pfizer/BioNTech
# 471                              NaN             Moderna, Pfizer/BioNTech
# 498                              NaN                      Pfizer/BioNTech
# 511                              NaN                      Pfizer/BioNTech
# 538                              NaN     Pfizer/BioNTech, Pifzer/BioNTech
# 564                              NaN             Moderna, Pfizer/BioNTech
# 588                              NaN                  Covaxin, Covishield
# 597                              NaN                              Sinovac
# 608                              NaN                      Pfizer/BioNTech
# 629                              NaN                      Pfizer/BioNTech
# 631                              NaN             Moderna, Pfizer/BioNTech
# 667                              NaN                      Pfizer/BioNTech
# 695                              NaN                      Pfizer/BioNTech
# 696                              NaN                      Pfizer/BioNTech
# 723                              NaN             Moderna, Pfizer/BioNTech
# 753                              NaN                      Pfizer/BioNTech
# 776                              NaN                      Pfizer/BioNTech
# 802                              NaN                      Pfizer/BioNTech
# 833                              NaN             Moderna, Pfizer/BioNTech
# 850                              NaN  Oxford/AstraZeneca, Pfizer/BioNTech
# 891                              NaN                      Pfizer/BioNTech
# 917                              NaN                      Pfizer/BioNTech
# 940                              NaN                      Pfizer/BioNTech
# 945                              NaN                      Pfizer/BioNTech
# 971                              NaN                      Pfizer/BioNTech
# 998                              NaN                      Pfizer/BioNTech
# 1025                             NaN                            Sputnik V
# 1055                             NaN                      Pfizer/BioNTech
# 1067                             NaN  Oxford/AstraZeneca, Pfizer/BioNTech
# 1108                             NaN                      Pfizer/BioNTech
# 1124                             NaN                            Sinopharm
# 1136                             NaN                      Pfizer/BioNTech
# 1148                             NaN                      Pfizer/BioNTech
# 1166                             NaN                      Pfizer/BioNTech
# 1186                             NaN             Moderna, Pfizer/BioNTech
# 1205                             NaN                      Pfizer/BioNTech
# 1227                             NaN                      Pfizer/BioNTech
# 1257                             NaN                              Sinovac
# 1268                             NaN           Pfizer/BioNTech, Sinopharm
# 1287                             NaN  Oxford/AstraZeneca, Pfizer/BioNTech
# 1321                             NaN             Moderna, Pfizer/BioNTech
# 1356                             NaN  Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                             source_name  \
# 0                                    Ministry of Health
# 26                                   Ministry of Health
# 45                                   Ministry of Health
# 74                                            Sciensano
# 100         Regional governments via Coronavirus Brasil
# 108                                  Ministry of Health
# 134             COVID-19 Canada Open Data Working Group
# 175     Department of Statistics and Health Information
# 205                          National Health Commission
# 242                          National Health Commission
# 268                                  Ministry of Health
# 292                                  Ministry of Health
# 309                                  Ministry of Health
# 337                              Statens Serum Institut
# 365                               Government of Ecuador
# 367                    Government of the United Kingdom
# 401                               National Health Board
# 428                           THL via Helsingin Sanomat
# 451                                  Ministry of Health
# 471                                Robert Koch Institut
# 498                             Government of Gibraltar
# 511                                  Ministry of Health
# 538                               Government of Hungary
# 564                               Directorate of Health
# 588                                  Ministry of Health
# 597                                  Ministry of Health
# 608                             Heath Service Executive
# 629                              Isle of Man Government
# 631                                Government of Israel
# 667   Extraordinary commissioner for the Covid-19 em...
# 695                                  Ministry of Health
# 696                             National Health Service
# 723                                  Ministry of Health
# 753                            Government of Luxembourg
# 776                                  Ministry of Health
# 802                                 Secretary of Health
# 833   National Institute for Public Health and the E...
# 850                    Government of the United Kingdom
# 891                Norwegian Institute of Public Health
# 917                                  Ministry of Health
# 940                                  Ministry of Health
# 945                                  Ministry of Health
# 971                             National Health Service
# 998                               Government of Romania
# 1025                     Russian Direct Investment Fund
# 1055                               Saudi Health Council
# 1067                   Government of the United Kingdom
# 1108                               Government of Serbia
# 1124                Extended Programme for Immunisation
# 1136                                 Ministry of Health
# 1148                                 Ministry of Health
# 1166  National Institute of Public Health, via Sledi...
# 1186                                 Ministry of Health
# 1205                     Public Health Agency of Sweden
# 1227                    Federal Office of Public Health
# 1257              COVID-19 Vaccine Information Platform
# 1268  National Emergency Crisis and Disaster Managem...
# 1287                   Government of the United Kingdom
# 1321         Centers for Disease Control and Prevention
# 1356                   Government of the United Kingdom
#
#                                          source_website DownloadFrom  USA_Flag
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 26    https://info.gesundheitsministerium.gv.at/open...       Kaggle       NaN
# 45    https://twitter.com/MOH_Bahrain/status/1351989...       Kaggle       NaN
# 74    https://datastudio.google.com/embed/u/0/report...       Kaggle       NaN
# 100                  https://coronavirusbra1.github.io/       Kaggle       NaN
# 108                https://coronavirus.bg/bg/statistika       Kaggle       NaN
# 134          https://github.com/ishaberry/Covid19Canada       Kaggle       NaN
# 175   https://informesdeis.minsal.cl/SASVisualAnalyt...       Kaggle       NaN
# 205   https://www.globaltimes.cn/page/202101/1213364...       Kaggle       NaN
# 242   https://www.larepublica.net/noticia/sube-a-293...       Kaggle       NaN
# 268   https://vlada.gov.hr/vijesti/mjere-ce-se-defin...       Kaggle       NaN
# 292   https://www.pio.gov.cy/%CE%B1%CE%BD%CE%B1%CE%B...       Kaggle       NaN
# 309        https://onemocneni-aktualne.mzcr.cz/covid-19       Kaggle       NaN
# 337   https://covid19.ssi.dk/overvagningsdata/vaccin...       Kaggle       NaN
# 365   https://twitter.com/munozmalejandra/status/135...       Kaggle       NaN
# 367   https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 401               https://www.terviseamet.ee/et/uudised       Kaggle       NaN
# 428   https://github.com/HS-Datadesk/koronavirus-avo...       Kaggle       NaN
# 451   https://www.data.gouv.fr/fr/datasets/donnees-r...       Kaggle       NaN
# 471   https://www.rki.de/DE/Content/InfAZ/N/Neuartig...       Kaggle       NaN
# 498   https://twitter.com/GibraltarGov/status/135297...       Kaggle       NaN
# 511       https://www.data.gov.gr/datasets/mdg_emvolio/       Kaggle       NaN
# 538   https://koronavirus.gov.hu/cikkek/1344-fovel-e...       Kaggle       NaN
# 564   https://www.covid.is/tolulegar-upplysingar-bol...       Kaggle       NaN
# 588                           https://www.mohfw.gov.in/       Kaggle       NaN
# 597   https://sehatnegeriku.kemkes.go.id/baca/rilis-...       Kaggle       NaN
# 608      https://covid19ireland-geohive.hub.arcgis.com/       Kaggle       NaN
# 629   https://covid19.gov.im/general-information/lat...       Kaggle       NaN
# 631   https://datadashboard.health.gov.il/COVID-19/g...       Kaggle       NaN
# 667   https://github.com/italia/covid19-opendata-vac...       Kaggle       NaN
# 695   https://alqabas.com/article/5828928-2500-شخص-ح...       Kaggle       NaN
# 696   http://www.vmnvd.gov.lv/lv/covid-19/1486-vakci...       Kaggle       NaN
# 723   https://ls-osp-sdg.maps.arcgis.com/apps/opsdas...       Kaggle       NaN
# 753   https://data.public.lu/fr/datasets/r/fa53afaa-...       Kaggle       NaN
# 776   https://deputyprimeminister.gov.mt/en/health-p...       Kaggle       NaN
# 802   https://www.gob.mx/salud/prensa/031-este-sabad...       Kaggle       NaN
# 833   https://www.rivm.nl/covid-19-vaccinatie/cijfer...       Kaggle       NaN
# 850   https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 891   https://www.fhi.no/sv/vaksine/koronavaksinasjo...       Kaggle       NaN
# 917   https://twitter.com/OmaniMOH/status/1352168458...       Kaggle       NaN
# 940   https://twitter.com/MINSAPma/status/1353136663...       Kaggle       NaN
# 945   https://www.gov.pl/web/szczepimysie/raport-szc...       Kaggle       NaN
# 971   https://esriportugal.maps.arcgis.com/apps/opsd...       Kaggle       NaN
# 998   https://vaccinare-covid.gov.ro/comunicate-ofic...       Kaggle       NaN
# 1025  https://twitter.com/redouad/status/13500305399...       Kaggle       NaN
# 1055                              https://coronamap.sa/       Kaggle       NaN
# 1067  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1108  https://www.telegraf.rs/vesti/srbija/3292522-u...       Kaggle       NaN
# 1124  https://www.facebook.com/sbc.sc/photos/1754801...       Kaggle       NaN
# 1136  https://www.moh.gov.sg/news-highlights/details...       Kaggle       NaN
# 1148  https://github.com/Institut-Zdravotnych-Analyz...       Kaggle       NaN
# 1166                 https://covid-19.sledilnik.org/en/       Kaggle       NaN
# 1186  https://www.mscbs.gob.es/profesionales/saludPu...       Kaggle       NaN
# 1205  https://www.folkhalsomyndigheten.se/smittskydd...       Kaggle       NaN
# 1227  https://www.bag.admin.ch/dam/bag/fr/dokumente/...       Kaggle       NaN
# 1257                  https://covid19asi.saglik.gov.tr/       Kaggle       NaN
# 1268                    https://covid19.ncema.gov.ae/en       Kaggle       NaN
# 1287  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1321  https://covid.cdc.gov/covid-data-tracker/#vacc...       Kaggle       1.0
# 1356  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN

# %%
#pratice
# let's see if there are duplicated rows based on country

# %% [markdown]
# _How to look at the duplicates rows_
#
# duplicated function return boolean Series denoting duplicate rows. First occurence will be marked as non-duplicate 'False' and other occurence will be marked as duplicates 'True'. Here we will check the duplicated rows based on country column itself.

# %%
df.duplicated(subset=['country'])
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1392     True
# 1393     True
# 1394     True
# 1395     True
# 1396     True
# Length: 1397, dtype: bool

# %%
df.head()
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0                NaN
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
# 4  Argentina      ARG  2021-01-02                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN             15656.0
# 2                      NaN                     NaN             15656.0
# 3                      NaN                     NaN             11070.0
# 4                      NaN                     NaN              8776.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                            NaN
# 1                             NaN                            NaN
# 2                            0.07                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                           346.0
# 2                                  NaN                           346.0
# 3                                  NaN                           245.0
# 4                                  NaN                           194.0
#
#     vaccines         source_name  \
# 0  Sputnik V  Ministry of Health
# 1  Sputnik V  Ministry of Health
# 2  Sputnik V  Ministry of Health
# 3  Sputnik V  Ministry of Health
# 4  Sputnik V  Ministry of Health
#
#                                       source_website DownloadFrom  USA_Flag
# 0  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 1  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 2  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 3  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 4  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN

# %%
df[df.duplicated(subset=['country'])]
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 1     Argentina      ARG  2020-12-30                 NaN                NaN
# 2     Argentina      ARG  2020-12-31             32013.0                NaN
# 3     Argentina      ARG  2021-01-01                 NaN                NaN
# 4     Argentina      ARG  2021-01-02                 NaN                NaN
# 5     Argentina      ARG  2021-01-03                 NaN                NaN
# ...         ...      ...         ...                 ...                ...
# 1392      Wales      NaN  2021-01-18            162197.0           161932.0
# 1393      Wales      NaN  2021-01-19            176186.0           175816.0
# 1394      Wales      NaN  2021-01-20            190831.0           190435.0
# 1395      Wales      NaN  2021-01-21            212732.0           212317.0
# 1396      Wales      NaN  2021-01-22            241016.0           240547.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1                         NaN                     NaN             15656.0
# 2                         NaN                     NaN             15656.0
# 3                         NaN                     NaN             11070.0
# 4                         NaN                     NaN              8776.0
# 5                         NaN                     NaN              7400.0
# ...                       ...                     ...                 ...
# 1392                    265.0                 10259.0             10123.0
# 1393                    370.0                 13989.0             10672.0
# 1394                    396.0                 14645.0             11105.0
# 1395                    415.0                 21901.0             12318.0
# 1396                    469.0                 28284.0             15148.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1                                NaN                            NaN
# 2                               0.07                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# 5                                NaN                            NaN
# ...                              ...                            ...
# 1392                            5.14                           5.14
# 1393                            5.59                           5.58
# 1394                            6.05                           6.04
# 1395                            6.75                           6.73
# 1396                            7.64                           7.63
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 1                                     NaN                           346.0
# 2                                     NaN                           346.0
# 3                                     NaN                           245.0
# 4                                     NaN                           194.0
# 5                                     NaN                           164.0
# ...                                   ...                             ...
# 1392                                 0.01                          3211.0
# 1393                                 0.01                          3385.0
# 1394                                 0.01                          3522.0
# 1395                                 0.01                          3907.0
# 1396                                 0.01                          4804.0
#
#                                  vaccines                       source_name  \
# 1                               Sputnik V                Ministry of Health
# 2                               Sputnik V                Ministry of Health
# 3                               Sputnik V                Ministry of Health
# 4                               Sputnik V                Ministry of Health
# 5                               Sputnik V                Ministry of Health
# ...                                   ...                               ...
# 1392  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1393  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1394  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1395  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1396  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website DownloadFrom  USA_Flag
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 5     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# ...                                                 ...          ...       ...
# 1392  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1393  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1394  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1395  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1396  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
#
# [1337 rows x 17 columns]

# %% [markdown]
# ## Summary functions
#
# <a id='SummaryFunctions'> </a>
#
# Pandas provides many simple "summary functions" (not an official name) which restructure the data in some useful way. For example, consider the describe() method:

# %%
#let check the descriptive statitsics for total_vaccinations
df.total_vaccinations.describe()
# Out:
# count    9.190000e+02
# mean     5.894958e+05
# std      1.857483e+06
# min      0.000000e+00
# 25%      1.501150e+04
# 50%      6.282200e+04
# 75%      2.787140e+05
# max      2.053799e+07
# Name: total_vaccinations, dtype: float64

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        9.190000e+02       8.850000e+02             2.230000e+02
# mean         5.894958e+05       5.516406e+05             1.676446e+05
# std          1.857483e+06       1.673335e+06             4.188368e+05
# min          0.000000e+00       0.000000e+00             2.000000e+00
# 25%          1.501150e+04       1.502300e+04             2.139000e+03
# 50%          6.282200e+04       6.075300e+04             8.449000e+03
# 75%          2.787140e+05       2.824500e+05             1.903020e+05
# max          2.053799e+07       1.739034e+07             3.027865e+06
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            7.380000e+02        1.337000e+03
# mean             4.735601e+04        4.217337e+04
# std              1.319281e+05        1.116745e+05
# min              0.000000e+00        1.000000e+00
# 25%              1.706000e+03        1.662000e+03
# 50%              7.627000e+03        5.512000e+03
# 75%              3.785650e+04        2.529900e+04
# max              1.561585e+06        1.057387e+06
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                      919.000000                     885.000000
# mean                         2.434276                       2.303085
# std                          5.064139                       4.548534
# min                          0.000000                       0.000000
# 25%                          0.215000                       0.220000
# 50%                          0.790000                       0.800000
# 75%                          1.955000                       1.950000
# max                         39.790000                      28.860000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# count                           223.000000                     1337.000000
# mean                              0.650179                     1432.382947
# std                               1.533988                     3120.828782
# min                               0.000000                        0.000000
# 25%                               0.015000                      262.000000
# 50%                               0.070000                      640.000000
# 75%                               0.685000                     1065.000000
# max                              10.940000                    30869.000000
#
#        USA_Flag
# count      35.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0

# %%
#Return the median of the values
#Exclude NA/null values when computing the result.
df.median()
# Out:
# total_vaccinations                     62822.00
# people_vaccinated                      60753.00
# people_fully_vaccinated                 8449.00
# daily_vaccinations_raw                  7627.00
# daily_vaccinations                      5512.00
# total_vaccinations_per_hundred             0.79
# people_vaccinated_per_hundred              0.80
# people_fully_vaccinated_per_hundred        0.07
# daily_vaccinations_per_million           640.00
# USA_Flag                                   1.00
# dtype: float64

# %%
#To see a list of unique values we can use the unique() function:
df.vaccines.unique()
# Out:
# array(['Sputnik V', 'Pfizer/BioNTech', 'Pfizer/BioNTech, Sinopharm',
#        'Sinovac', 'Moderna, Pfizer/BioNTech', 'CNBG, Sinovac',
#        'Oxford/AstraZeneca, Pfizer/BioNTech',
#        'Pfizer/BioNTech, Pifzer/BioNTech', 'Covaxin, Covishield',
#        'Sinopharm'], dtype=object)

# %%
# To see a list of unique values and how often they occur in the dataset, we can use the value_counts() method:
df.country.value_counts()
# Out:
# Scotland                41
# Canada                  41
# Northern Ireland        41
# Wales                   41
# China                   37
# Israel                  36
# United States           35
# United Kingdom          34
# England                 34
# Mexico                  31
# Chile                   30
# Russia                  30
# Switzerland             30
# Lithuania               30
# Bahrain                 29
# Italy                   28
# Czechia                 28
# Denmark                 28
# Portugal                27
# Romania                 27
# Germany                 27
# Estonia                 27
# Latvia                  27
# Greece                  27
# Bulgaria                26
# Norway                  26
# Belgium                 26
# Argentina               26
# Poland                  26
# Malta                   26
# Costa Rica              26
# Hungary                 26
# Iceland                 24
# Croatia                 24
# Finland                 23
# Luxembourg              23
# Oman                    23
# Sweden                  22
# Ireland                 21
# Slovenia                20
# France                  20
# Austria                 19
# Spain                   19
# United Arab Emirates    19
# Slovakia                18
# Cyprus                  17
# Netherlands             17
# Serbia                  16
# Gibraltar               13
# Singapore               12
# Saudi Arabia            12
# Seychelles              12
# Indonesia               11
# Turkey                  11
# India                    9
# Brazil                   8
# Panama                   5
# Isle of Man              2
# Ecuador                  2
# Kuwait                   1
# Name: country, dtype: int64

# %% [markdown]
# # Missing Data
# <a id='MissingData'> </a>
#
# Entries missing values are given the value NaN, short for "Not a Number". For technical reasons these NaN values are always of the float64 dtype.
#
# Pandas provides some methods specific to missing data. To select NaN entries you can use pd.isnull() (or its companion pd.notnull()). This is meant to be used thusly:

# %%
df.head()
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0                NaN
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
# 4  Argentina      ARG  2021-01-02                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN             15656.0
# 2                      NaN                     NaN             15656.0
# 3                      NaN                     NaN             11070.0
# 4                      NaN                     NaN              8776.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                            NaN
# 1                             NaN                            NaN
# 2                            0.07                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                           346.0
# 2                                  NaN                           346.0
# 3                                  NaN                           245.0
# 4                                  NaN                           194.0
#
#     vaccines         source_name  \
# 0  Sputnik V  Ministry of Health
# 1  Sputnik V  Ministry of Health
# 2  Sputnik V  Ministry of Health
# 3  Sputnik V  Ministry of Health
# 4  Sputnik V  Ministry of Health
#
#                                       source_website DownloadFrom  USA_Flag
# 0  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 1  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 2  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 3  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 4  http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN

# %%
df.isnull()
#df.isnull()
#pd.isna(df)
# Out:
#       country  iso_code   date  total_vaccinations  people_vaccinated  \
# 0       False     False  False               False               True
# 1       False     False  False                True               True
# 2       False     False  False               False               True
# 3       False     False  False                True               True
# 4       False     False  False                True               True
# ...       ...       ...    ...                 ...                ...
# 1392    False      True  False               False              False
# 1393    False      True  False               False              False
# 1394    False      True  False               False              False
# 1395    False      True  False               False              False
# 1396    False      True  False               False              False
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                        True                    True                True
# 1                        True                    True               False
# 2                        True                    True               False
# 3                        True                    True               False
# 4                        True                    True               False
# ...                       ...                     ...                 ...
# 1392                    False                   False               False
# 1393                    False                   False               False
# 1394                    False                   False               False
# 1395                    False                   False               False
# 1396                    False                   False               False
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                              False                           True
# 1                               True                           True
# 2                              False                           True
# 3                               True                           True
# 4                               True                           True
# ...                              ...                            ...
# 1392                           False                          False
# 1393                           False                          False
# 1394                           False                          False
# 1395                           False                          False
# 1396                           False                          False
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                    True                            True
# 1                                    True                           False
# 2                                    True                           False
# 3                                    True                           False
# 4                                    True                           False
# ...                                   ...                             ...
# 1392                                False                           False
# 1393                                False                           False
# 1394                                False                           False
# 1395                                False                           False
# 1396                                False                           False
#
#       vaccines  source_name  source_website  DownloadFrom  USA_Flag
# 0        False        False           False         False      True
# 1        False        False           False         False      True
# 2        False        False           False         False      True
# 3        False        False           False         False      True
# 4        False        False           False         False      True
# ...        ...          ...             ...           ...       ...
# 1392     False        False           False         False      True
# 1393     False        False           False         False      True
# 1394     False        False           False         False      True
# 1395     False        False           False         False      True
# 1396     False        False           False         False      True
#
# [1397 rows x 17 columns]

# %%
df.notnull()
# Out:
#       country  iso_code  date  total_vaccinations  people_vaccinated  \
# 0        True      True  True                True              False
# 1        True      True  True               False              False
# 2        True      True  True                True              False
# 3        True      True  True               False              False
# 4        True      True  True               False              False
# ...       ...       ...   ...                 ...                ...
# 1392     True     False  True                True               True
# 1393     True     False  True                True               True
# 1394     True     False  True                True               True
# 1395     True     False  True                True               True
# 1396     True     False  True                True               True
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                       False                   False               False
# 1                       False                   False                True
# 2                       False                   False                True
# 3                       False                   False                True
# 4                       False                   False                True
# ...                       ...                     ...                 ...
# 1392                     True                    True                True
# 1393                     True                    True                True
# 1394                     True                    True                True
# 1395                     True                    True                True
# 1396                     True                    True                True
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               True                          False
# 1                              False                          False
# 2                               True                          False
# 3                              False                          False
# 4                              False                          False
# ...                              ...                            ...
# 1392                            True                           True
# 1393                            True                           True
# 1394                            True                           True
# 1395                            True                           True
# 1396                            True                           True
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                   False                           False
# 1                                   False                            True
# 2                                   False                            True
# 3                                   False                            True
# 4                                   False                            True
# ...                                   ...                             ...
# 1392                                 True                            True
# 1393                                 True                            True
# 1394                                 True                            True
# 1395                                 True                            True
# 1396                                 True                            True
#
#       vaccines  source_name  source_website  DownloadFrom  USA_Flag
# 0         True         True            True          True     False
# 1         True         True            True          True     False
# 2         True         True            True          True     False
# 3         True         True            True          True     False
# 4         True         True            True          True     False
# ...        ...          ...             ...           ...       ...
# 1392      True         True            True          True     False
# 1393      True         True            True          True     False
# 1394      True         True            True          True     False
# 1395      True         True            True          True     False
# 1396      True         True            True          True     False
#
# [1397 rows x 17 columns]

# %%
#Pratice
# how to extract records where daily_vaccinations_per_million is not null

# %% [markdown]
# Alternatively,we can use dropna() method to drop records where there are missing values

# %%
#by default, it will drop records whereever there is an NaN
df.dropna()
# Out:
#             country iso_code        date  total_vaccinations  \
# 1346  United States      USA  2021-01-14          11148991.0
# 1347  United States      USA  2021-01-15          12279180.0
# 1352  United States      USA  2021-01-20          16525281.0
# 1353  United States      USA  2021-01-21          17546374.0
# 1354  United States      USA  2021-01-22          19107959.0
# 1355  United States      USA  2021-01-23          20537990.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1346          9690757.0                1342086.0                870529.0
# 1347         10595866.0                1610524.0               1130189.0
# 1352         14270441.0                2161419.0                817693.0
# 1353         15053257.0                2394961.0               1021093.0
# 1354         16243093.0                2756953.0               1561585.0
# 1355         17390345.0                3027865.0               1430031.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 1346            747082.0                            3.37
# 1347            798707.0                            3.71
# 1352            892403.0                            4.99
# 1353            913912.0                            5.30
# 1354            975540.0                            5.77
# 1355           1057387.0                            6.20
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 1346                           2.93                                 0.41
# 1347                           3.20                                 0.49
# 1352                           4.31                                 0.65
# 1353                           4.55                                 0.72
# 1354                           4.91                                 0.83
# 1355                           5.25                                 0.91
#
#       daily_vaccinations_per_million                  vaccines  \
# 1346                          2257.0  Moderna, Pfizer/BioNTech
# 1347                          2413.0  Moderna, Pfizer/BioNTech
# 1352                          2696.0  Moderna, Pfizer/BioNTech
# 1353                          2761.0  Moderna, Pfizer/BioNTech
# 1354                          2947.0  Moderna, Pfizer/BioNTech
# 1355                          3194.0  Moderna, Pfizer/BioNTech
#
#                                      source_name  \
# 1346  Centers for Disease Control and Prevention
# 1347  Centers for Disease Control and Prevention
# 1352  Centers for Disease Control and Prevention
# 1353  Centers for Disease Control and Prevention
# 1354  Centers for Disease Control and Prevention
# 1355  Centers for Disease Control and Prevention
#
#                                          source_website DownloadFrom  USA_Flag
# 1346  https://covid.cdc.gov/covid-data-tracker/#vacc...       Kaggle       1.0
# 1347  https://covid.cdc.gov/covid-data-tracker/#vacc...       Kaggle       1.0
# 1352  https://covid.cdc.gov/covid-data-tracker/#vacc...       Kaggle       1.0
# 1353  https://covid.cdc.gov/covid-data-tracker/#vacc...       Kaggle       1.0
# 1354  https://covid.cdc.gov/covid-data-tracker/#vacc...       Kaggle       1.0
# 1355  https://covid.cdc.gov/covid-data-tracker/#vacc...       Kaggle       1.0

# %%
#Pratice
# how to only drop record if daily_vaccinations_per_million is missing

# %% [markdown]
# Replacing missing values is a common operation. Pandas provides a really handy method for this problem: fillna(). fillna() provides a few different strategies for mitigating such data. For example, we can simply replace each NaN with an "Unknown":

# %%
df.iso_code.unique()
# Out:
# array(['ARG', 'AUT', 'BHR', 'BEL', 'BRA', 'BGR', 'CAN', 'CHL', 'CHN',
#        'CRI', 'HRV', 'CYP', 'CZE', 'DNK', 'ECU', nan, 'EST', 'FIN', 'FRA',
#        'DEU', 'GIB', 'GRC', 'HUN', 'ISL', 'IND', 'IDN', 'IRL', 'IMN',
#        'ISR', 'ITA', 'KWT', 'LVA', 'LTU', 'LUX', 'MLT', 'MEX', 'NLD',
#        'NOR', 'OMN', 'PAN', 'POL', 'PRT', 'ROU', 'RUS', 'SAU', 'SRB',
#        'SYC', 'SGP', 'SVK', 'SVN', 'ESP', 'SWE', 'CHE', 'TUR', 'ARE',
#        'GBR', 'USA'], dtype=object)

# %%
df.iso_code.fillna("UNKNOWN")
# Out:
# 0           ARG
# 1           ARG
# 2           ARG
# 3           ARG
# 4           ARG
#          ...
# 1392    UNKNOWN
# 1393    UNKNOWN
# 1394    UNKNOWN
# 1395    UNKNOWN
# 1396    UNKNOWN
# Name: iso_code, Length: 1397, dtype: object

# %%
df.iso_code
# Out:
# 0       ARG
# 1       ARG
# 2       ARG
# 3       ARG
# 4       ARG
#        ...
# 1392    NaN
# 1393    NaN
# 1394    NaN
# 1395    NaN
# 1396    NaN
# Name: iso_code, Length: 1397, dtype: object

# %%
df.iso_code.fillna("UNKNOWN",inplace=True)

# %%
df.iso_code
# Out:
# 0           ARG
# 1           ARG
# 2           ARG
# 3           ARG
# 4           ARG
#          ...
# 1392    UNKNOWN
# 1393    UNKNOWN
# 1394    UNKNOWN
# 1395    UNKNOWN
# 1396    UNKNOWN
# Name: iso_code, Length: 1397, dtype: object

# %%
#Practice
#fill missing value in total_vaccinations with the mean of total_vaccinations

# %% [markdown]
# Alternatively, we may have a non-null value that we would like to replace. For example, suppose that we don't to have a unknown iso_code in our dataset then we can replace the 'UNKNOWN' iso_code to be 'ISO UNKNOWN'

# %%
df.iso_code.replace("UNKNOWN", "ISO UNKNOWN")
# Out:
# 0               ARG
# 1               ARG
# 2               ARG
# 3               ARG
# 4               ARG
#            ...
# 1392    ISO UNKNOWN
# 1393    ISO UNKNOWN
# 1394    ISO UNKNOWN
# 1395    ISO UNKNOWN
# 1396    ISO UNKNOWN
# Name: iso_code, Length: 1397, dtype: object

# %%
df.iso_code
# Out:
# 0           ARG
# 1           ARG
# 2           ARG
# 3           ARG
# 4           ARG
#          ...
# 1392    UNKNOWN
# 1393    UNKNOWN
# 1394    UNKNOWN
# 1395    UNKNOWN
# 1396    UNKNOWN
# Name: iso_code, Length: 1397, dtype: object

# %% [markdown]
# ## Map
#
# <a id='Map'> </a>
#
# A map is a term, borrowed from mathematics, for a function that takes one set of values and "maps" them to another set of values. In data science we often have a need for creating new representations from existing data, or for transforming data from the format it is in now to the format that we want it to be in later. Maps are what handle this work, making them extremely important for getting your work done!
#
# There are two mapping methods that you will use often.
#
# map() is the first, and slightly simpler one. For example, suppose that we wanted to calcualted a column that remean the total_vaccinations to 0 so we can easily see what country have total_vaccinations above the mean or below the mean in the dataset.
#
# The function you pass to map() should expect a single value from the Series (a point value, in the above example), and return a transformed version of that value. map() returns a new Series where all the values have been transformed by your function.

# %%
total_vaccinations_mean = df.total_vaccinations.mean()

# %%
#it doesn't modify the original data they're called on. 
df.total_vaccinations.map(lambda x: x - total_vaccinations_mean)
# Out:
# 0      -588795.76605
# 1                NaN
# 2      -557482.76605
# 3                NaN
# 4                NaN
#             ...
# 1392   -427298.76605
# 1393   -413309.76605
# 1394   -398664.76605
# 1395   -376763.76605
# 1396   -348479.76605
# Name: total_vaccinations, Length: 1397, dtype: float64

# %%
df.total_vaccinations
# Out:
# 0          700.0
# 1            NaN
# 2        32013.0
# 3            NaN
# 4            NaN
#           ...
# 1392    162197.0
# 1393    176186.0
# 1394    190831.0
# 1395    212732.0
# 1396    241016.0
# Name: total_vaccinations, Length: 1397, dtype: float64

# %% [markdown]
# apply() is the equivalent method if we want to transform a whole DataFrame by calling a custom method on each row.

# %%
def remean_total_vaccinations(row):
    row.total_vaccinations = row.total_vaccinations - total_vaccinations_mean
    return row

# %%
df.apply(remean_total_vaccinations, axis='columns')
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Argentina      ARG  2020-12-29       -588795.76605                NaN
# 1     Argentina      ARG  2020-12-30                 NaN                NaN
# 2     Argentina      ARG  2020-12-31       -557482.76605                NaN
# 3     Argentina      ARG  2021-01-01                 NaN                NaN
# 4     Argentina      ARG  2021-01-02                 NaN                NaN
# ...         ...      ...         ...                 ...                ...
# 1392      Wales  UNKNOWN  2021-01-18       -427298.76605           161932.0
# 1393      Wales  UNKNOWN  2021-01-19       -413309.76605           175816.0
# 1394      Wales  UNKNOWN  2021-01-20       -398664.76605           190435.0
# 1395      Wales  UNKNOWN  2021-01-21       -376763.76605           212317.0
# 1396      Wales  UNKNOWN  2021-01-22       -348479.76605           240547.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN             15656.0
# 2                         NaN                     NaN             15656.0
# 3                         NaN                     NaN             11070.0
# 4                         NaN                     NaN              8776.0
# ...                       ...                     ...                 ...
# 1392                    265.0                 10259.0             10123.0
# 1393                    370.0                 13989.0             10672.0
# 1394                    396.0                 14645.0             11105.0
# 1395                    415.0                 21901.0             12318.0
# 1396                    469.0                 28284.0             15148.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                            NaN
# 1                                NaN                            NaN
# 2                               0.07                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 1392                            5.14                           5.14
# 1393                            5.59                           5.58
# 1394                            6.05                           6.04
# 1395                            6.75                           6.73
# 1396                            7.64                           7.63
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                           346.0
# 2                                     NaN                           346.0
# 3                                     NaN                           245.0
# 4                                     NaN                           194.0
# ...                                   ...                             ...
# 1392                                 0.01                          3211.0
# 1393                                 0.01                          3385.0
# 1394                                 0.01                          3522.0
# 1395                                 0.01                          3907.0
# 1396                                 0.01                          4804.0
#
#                                  vaccines                       source_name  \
# 0                               Sputnik V                Ministry of Health
# 1                               Sputnik V                Ministry of Health
# 2                               Sputnik V                Ministry of Health
# 3                               Sputnik V                Ministry of Health
# 4                               Sputnik V                Ministry of Health
# ...                                   ...                               ...
# 1392  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1393  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1394  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1395  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1396  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website DownloadFrom  USA_Flag
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# ...                                                 ...          ...       ...
# 1392  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1393  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1394  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1395  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1396  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
#
# [1397 rows x 17 columns]

# %%
#Pratice
# remean columns daily_vaccinations_per_million referencing to the code above

# %% [markdown]
# # Groupby
#
# <a id='GroupBy'> </a>
#
# Maps allow us to transform data in a DataFrame or Series one value at a time for an entire column. However, often we want to group our data, and then do something specific to the group the data is in.

# %% [markdown]
# #### Now you can use the .groupby() method to group rows together based off of a column name. This will create a DataFrameGroupBy object:

# %%
df.groupby('country')

# %%
#You can save this object as a new variable:
by_country = df.groupby("country")

# %%
# then call aggregate methods off the object:
by_country.total_vaccinations.median()
# Out:
# country
# Argentina                183796.0
# Austria                   74100.0
# Bahrain                   68472.0
# Belgium                   28898.0
# Brazil                    20006.5
# Bulgaria                  17038.0
# Canada                   117727.0
# Chile                     18526.0
# China                   9000000.0
# Costa Rica                 9751.0
# Croatia                   32276.5
# Cyprus                     8130.5
# Czechia                   47583.0
# Denmark                  117201.5
# Ecuador                      54.0
# England                 3352029.5
# Estonia                   10860.5
# Finland                   23126.0
# France                   282691.5
# Germany                  607874.0
# Gibraltar                  5847.0
# Greece                    42121.5
# Hungary                   82754.0
# Iceland                    6205.0
# India                    674835.0
# Indonesia                 66000.0
# Ireland                   40000.0
# Isle of Man                3603.0
# Israel                  1548990.5
# Italy                    627735.5
# Kuwait                     2500.0
# Latvia                     9949.0
# Lithuania                 25649.0
# Luxembourg                 3494.0
# Malta                     12353.5
# Mexico                    87060.0
# Netherlands               40250.0
# Northern Ireland         133831.0
# Norway                    22562.5
# Oman                      15001.5
# Panama                     2728.0
# Poland                   203053.0
# Portugal                  42035.0
# Romania                  108294.0
# Russia                   426000.0
# Saudi Arabia             158099.5
# Scotland                 211397.0
# Serbia                    44611.0
# Seychelles                 5500.0
# Singapore                  6200.0
# Slovakia                  42989.0
# Slovenia                  27011.5
# Spain                    628912.0
# Sweden                    55297.5
# Switzerland               88000.0
# Turkey                   832412.0
# United Arab Emirates    1596910.0
# United Kingdom          3842310.0
# United States           6303824.5
# Wales                    113094.0
# Name: total_vaccinations, dtype: float64

# %%
type(by_country.total_vaccinations.median())
# Out:
# pandas.core.series.Series

# %%
by_country.total_vaccinations.median().reset_index()
# Out:
#                  country  total_vaccinations
# 0              Argentina            183796.0
# 1                Austria             74100.0
# 2                Bahrain             68472.0
# 3                Belgium             28898.0
# 4                 Brazil             20006.5
# 5               Bulgaria             17038.0
# 6                 Canada            117727.0
# 7                  Chile             18526.0
# 8                  China           9000000.0
# 9             Costa Rica              9751.0
# 10               Croatia             32276.5
# 11                Cyprus              8130.5
# 12               Czechia             47583.0
# 13               Denmark            117201.5
# 14               Ecuador                54.0
# 15               England           3352029.5
# 16               Estonia             10860.5
# 17               Finland             23126.0
# 18                France            282691.5
# 19               Germany            607874.0
# 20             Gibraltar              5847.0
# 21                Greece             42121.5
# 22               Hungary             82754.0
# 23               Iceland              6205.0
# 24                 India            674835.0
# 25             Indonesia             66000.0
# 26               Ireland             40000.0
# 27           Isle of Man              3603.0
# 28                Israel           1548990.5
# 29                 Italy            627735.5
# 30                Kuwait              2500.0
# 31                Latvia              9949.0
# 32             Lithuania             25649.0
# 33            Luxembourg              3494.0
# 34                 Malta             12353.5
# 35                Mexico             87060.0
# 36           Netherlands             40250.0
# 37      Northern Ireland            133831.0
# 38                Norway             22562.5
# 39                  Oman             15001.5
# 40                Panama              2728.0
# 41                Poland            203053.0
# 42              Portugal             42035.0
# 43               Romania            108294.0
# 44                Russia            426000.0
# 45          Saudi Arabia            158099.5
# 46              Scotland            211397.0
# 47                Serbia             44611.0
# 48            Seychelles              5500.0
# 49             Singapore              6200.0
# 50              Slovakia             42989.0
# 51              Slovenia             27011.5
# 52                 Spain            628912.0
# 53                Sweden             55297.5
# 54           Switzerland             88000.0
# 55                Turkey            832412.0
# 56  United Arab Emirates           1596910.0
# 57        United Kingdom           3842310.0
# 58         United States           6303824.5
# 59                 Wales            113094.0

# %%
df.groupby("country").total_vaccinations.max()
# Out:
# country
# Argentina                 288064.0
# Austria                   169549.0
# Bahrain                   144130.0
# Belgium                   174307.0
# Brazil                    537774.0
# Bulgaria                   26119.0
# Canada                    801238.0
# Chile                      63047.0
# China                   15000000.0
# Costa Rica                 29389.0
# Croatia                    64951.0
# Cyprus                     17379.0
# Czechia                   192267.0
# Denmark                   196167.0
# Ecuador                      108.0
# England                  5526071.0
# Estonia                    25704.0
# Finland                    91260.0
# France                   1008720.0
# Germany                  1632777.0
# Gibraltar                   8877.0
# Greece                    157388.0
# Hungary                   150128.0
# Iceland                     8249.0
# India                    1582201.0
# Indonesia                 132000.0
# Ireland                   121900.0
# Isle of Man                 3648.0
# Israel                   3444194.0
# Italy                    1343880.0
# Kuwait                      2500.0
# Latvia                     19022.0
# Lithuania                  67036.0
# Luxembourg                  6897.0
# Malta                      17767.0
# Mexico                    618768.0
# Netherlands               135000.0
# Northern Ireland          177026.0
# Norway                     73844.0
# Oman                       29548.0
# Panama                      5594.0
# Poland                    684277.0
# Portugal                  232725.0
# Romania                   418885.0
# Russia                   1000000.0
# Saudi Arabia              295530.0
# Scotland                  385855.0
# Serbia                    163355.0
# Seychelles                 13163.0
# Singapore                  60000.0
# Slovakia                   92167.0
# Slovenia                   54839.0
# Spain                    1165825.0
# Sweden                    146775.0
# Switzerland               169783.0
# Turkey                   1226883.0
# United Arab Emirates     2426798.0
# United Kingdom           6329968.0
# United States           20537990.0
# Wales                     241016.0
# Name: total_vaccinations, dtype: float64

# %%
#Pratice
# use describe method to total_vaccinations column breakdown by country

# %% [markdown]
# _By default, group by column will be set as index;but you can set the as_index option to be false_

# %%
df.groupby("country",as_index=False).total_vaccinations.max()
# Out:
#                  country  total_vaccinations
# 0              Argentina            288064.0
# 1                Austria            169549.0
# 2                Bahrain            144130.0
# 3                Belgium            174307.0
# 4                 Brazil            537774.0
# 5               Bulgaria             26119.0
# 6                 Canada            801238.0
# 7                  Chile             63047.0
# 8                  China          15000000.0
# 9             Costa Rica             29389.0
# 10               Croatia             64951.0
# 11                Cyprus             17379.0
# 12               Czechia            192267.0
# 13               Denmark            196167.0
# 14               Ecuador               108.0
# 15               England           5526071.0
# 16               Estonia             25704.0
# 17               Finland             91260.0
# 18                France           1008720.0
# 19               Germany           1632777.0
# 20             Gibraltar              8877.0
# 21                Greece            157388.0
# 22               Hungary            150128.0
# 23               Iceland              8249.0
# 24                 India           1582201.0
# 25             Indonesia            132000.0
# 26               Ireland            121900.0
# 27           Isle of Man              3648.0
# 28                Israel           3444194.0
# 29                 Italy           1343880.0
# 30                Kuwait              2500.0
# 31                Latvia             19022.0
# 32             Lithuania             67036.0
# 33            Luxembourg              6897.0
# 34                 Malta             17767.0
# 35                Mexico            618768.0
# 36           Netherlands            135000.0
# 37      Northern Ireland            177026.0
# 38                Norway             73844.0
# 39                  Oman             29548.0
# 40                Panama              5594.0
# 41                Poland            684277.0
# 42              Portugal            232725.0
# 43               Romania            418885.0
# 44                Russia           1000000.0
# 45          Saudi Arabia            295530.0
# 46              Scotland            385855.0
# 47                Serbia            163355.0
# 48            Seychelles             13163.0
# 49             Singapore             60000.0
# 50              Slovakia             92167.0
# 51              Slovenia             54839.0
# 52                 Spain           1165825.0
# 53                Sweden            146775.0
# 54           Switzerland            169783.0
# 55                Turkey           1226883.0
# 56  United Arab Emirates           2426798.0
# 57        United Kingdom           6329968.0
# 58         United States          20537990.0
# 59                 Wales            241016.0

# %%
#similarily, you can use syntax below
df.groupby("country").total_vaccinations.max().reset_index()
# Out:
#                  country  total_vaccinations
# 0              Argentina            288064.0
# 1                Austria            169549.0
# 2                Bahrain            144130.0
# 3                Belgium            174307.0
# 4                 Brazil            537774.0
# 5               Bulgaria             26119.0
# 6                 Canada            801238.0
# 7                  Chile             63047.0
# 8                  China          15000000.0
# 9             Costa Rica             29389.0
# 10               Croatia             64951.0
# 11                Cyprus             17379.0
# 12               Czechia            192267.0
# 13               Denmark            196167.0
# 14               Ecuador               108.0
# 15               England           5526071.0
# 16               Estonia             25704.0
# 17               Finland             91260.0
# 18                France           1008720.0
# 19               Germany           1632777.0
# 20             Gibraltar              8877.0
# 21                Greece            157388.0
# 22               Hungary            150128.0
# 23               Iceland              8249.0
# 24                 India           1582201.0
# 25             Indonesia            132000.0
# 26               Ireland            121900.0
# 27           Isle of Man              3648.0
# 28                Israel           3444194.0
# 29                 Italy           1343880.0
# 30                Kuwait              2500.0
# 31                Latvia             19022.0
# 32             Lithuania             67036.0
# 33            Luxembourg              6897.0
# 34                 Malta             17767.0
# 35                Mexico            618768.0
# 36           Netherlands            135000.0
# 37      Northern Ireland            177026.0
# 38                Norway             73844.0
# 39                  Oman             29548.0
# 40                Panama              5594.0
# 41                Poland            684277.0
# 42              Portugal            232725.0
# 43               Romania            418885.0
# 44                Russia           1000000.0
# 45          Saudi Arabia            295530.0
# 46              Scotland            385855.0
# 47                Serbia            163355.0
# 48            Seychelles             13163.0
# 49             Singapore             60000.0
# 50              Slovakia             92167.0
# 51              Slovenia             54839.0
# 52                 Spain           1165825.0
# 53                Sweden            146775.0
# 54           Switzerland            169783.0
# 55                Turkey           1226883.0
# 56  United Arab Emirates           2426798.0
# 57        United Kingdom           6329968.0
# 58         United States          20537990.0
# 59                 Wales            241016.0

# %% [markdown]
# # Sorting
#
# <a id='Sort'> </a>
#
# Looking again at max total vaccination in each country we can see that grouping returns data in index order, not in value order. That is to say, when outputting the result of a groupby, the order of the rows is dependent on the values in the index, not in the data.
#
# To get data in the order want it in we can sort it ourselves. The sort_values() method is handy for this.

# %%
df.groupby("country").total_vaccinations.max().reset_index(name='total_vaccinations_max')
# Out:
#                  country  total_vaccinations_max
# 0              Argentina                288064.0
# 1                Austria                169549.0
# 2                Bahrain                144130.0
# 3                Belgium                174307.0
# 4                 Brazil                537774.0
# 5               Bulgaria                 26119.0
# 6                 Canada                801238.0
# 7                  Chile                 63047.0
# 8                  China              15000000.0
# 9             Costa Rica                 29389.0
# 10               Croatia                 64951.0
# 11                Cyprus                 17379.0
# 12               Czechia                192267.0
# 13               Denmark                196167.0
# 14               Ecuador                   108.0
# 15               England               5526071.0
# 16               Estonia                 25704.0
# 17               Finland                 91260.0
# 18                France               1008720.0
# 19               Germany               1632777.0
# 20             Gibraltar                  8877.0
# 21                Greece                157388.0
# 22               Hungary                150128.0
# 23               Iceland                  8249.0
# 24                 India               1582201.0
# 25             Indonesia                132000.0
# 26               Ireland                121900.0
# 27           Isle of Man                  3648.0
# 28                Israel               3444194.0
# 29                 Italy               1343880.0
# 30                Kuwait                  2500.0
# 31                Latvia                 19022.0
# 32             Lithuania                 67036.0
# 33            Luxembourg                  6897.0
# 34                 Malta                 17767.0
# 35                Mexico                618768.0
# 36           Netherlands                135000.0
# 37      Northern Ireland                177026.0
# 38                Norway                 73844.0
# 39                  Oman                 29548.0
# 40                Panama                  5594.0
# 41                Poland                684277.0
# 42              Portugal                232725.0
# 43               Romania                418885.0
# 44                Russia               1000000.0
# 45          Saudi Arabia                295530.0
# 46              Scotland                385855.0
# 47                Serbia                163355.0
# 48            Seychelles                 13163.0
# 49             Singapore                 60000.0
# 50              Slovakia                 92167.0
# 51              Slovenia                 54839.0
# 52                 Spain               1165825.0
# 53                Sweden                146775.0
# 54           Switzerland                169783.0
# 55                Turkey               1226883.0
# 56  United Arab Emirates               2426798.0
# 57        United Kingdom               6329968.0
# 58         United States              20537990.0
# 59                 Wales                241016.0

# %%
by_country_totalvaccinations_max=df.groupby("country").total_vaccinations.max().reset_index(name='total_vaccinations_max')
by_country_totalvaccinations_max.sort_values('total_vaccinations_max')
# Out:
#                  country  total_vaccinations_max
# 14               Ecuador                   108.0
# 30                Kuwait                  2500.0
# 27           Isle of Man                  3648.0
# 40                Panama                  5594.0
# 33            Luxembourg                  6897.0
# 23               Iceland                  8249.0
# 20             Gibraltar                  8877.0
# 48            Seychelles                 13163.0
# 11                Cyprus                 17379.0
# 34                 Malta                 17767.0
# 31                Latvia                 19022.0
# 16               Estonia                 25704.0
# 5               Bulgaria                 26119.0
# 9             Costa Rica                 29389.0
# 39                  Oman                 29548.0
# 51              Slovenia                 54839.0
# 49             Singapore                 60000.0
# 7                  Chile                 63047.0
# 10               Croatia                 64951.0
# 32             Lithuania                 67036.0
# 38                Norway                 73844.0
# 17               Finland                 91260.0
# 50              Slovakia                 92167.0
# 26               Ireland                121900.0
# 25             Indonesia                132000.0
# 36           Netherlands                135000.0
# 2                Bahrain                144130.0
# 53                Sweden                146775.0
# 22               Hungary                150128.0
# 21                Greece                157388.0
# 47                Serbia                163355.0
# 1                Austria                169549.0
# 54           Switzerland                169783.0
# 3                Belgium                174307.0
# 37      Northern Ireland                177026.0
# 12               Czechia                192267.0
# 13               Denmark                196167.0
# 42              Portugal                232725.0
# 59                 Wales                241016.0
# 0              Argentina                288064.0
# 45          Saudi Arabia                295530.0
# 46              Scotland                385855.0
# 43               Romania                418885.0
# 4                 Brazil                537774.0
# 35                Mexico                618768.0
# 41                Poland                684277.0
# 6                 Canada                801238.0
# 44                Russia               1000000.0
# 18                France               1008720.0
# 52                 Spain               1165825.0
# 55                Turkey               1226883.0
# 29                 Italy               1343880.0
# 24                 India               1582201.0
# 19               Germany               1632777.0
# 56  United Arab Emirates               2426798.0
# 28                Israel               3444194.0
# 15               England               5526071.0
# 57        United Kingdom               6329968.0
# 8                  China              15000000.0
# 58         United States              20537990.0

# %%
#Practice
# Can you sort above dataframe in a descending order of total_vaccinations

# %% [markdown]
# # Merging, Joining, and Concatenating
# <a id='MergeJoinConcat'> </a>
#
# There are 3 main ways of combining DataFrames together: Merging, Joining and Concatenating.

# %% [markdown]
# ## Merging
#
# <a id='Merging'> </a>
#
# You can use merge() any time you want to do database-like join operations. It’s the most flexible of the three operations you’ll learn.
#
# When you want to combine data objects based on one or more keys in a similar way to a relational database, merge() is the tool you need. More specifically, merge() is most useful when you want to combine rows that share data.
#
# You can achieve both many-to-one and many-to-many joins with merge(). In a many-to-one join, one of your datasets will have many rows in the merge column that repeat the same values (such as 1, 1, 3, 5, 5), while the merge column in the other dataset will not have repeat values (such as 1, 3, 5).
#
# In a many-to-many join, both of your merge columns will have repeat values. These merges are more complex and result in the Cartesian product of the joined rows.
#
# This means that, after the merge, you’ll have every combination of rows that share the same value in the key column. You’ll see this in action in the examples below.
#
# What makes merge() so flexible is the sheer number of options for defining the behavior of your merge. While the list can seem daunting, with practice you’ll be able to expertly merge datasets of all kinds.
#
# When you use merge(), you’ll provide two required arguments:
#
# - The left DataFrame
# - The right DataFrame
# - how: This defines what kind of merge to make. It defaults to 'inner', but other possible options include 'outer', 'left', and 'right'.

# %% [markdown]
# Before getting into the details of how to use merge(), you should first understand the various forms of joins:
#
# - inner
# - outer
# - left
# - right

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's define two dataframes:
#  - one contains the maximum total vaccinations breakdown by country
#  - one contains the minimum total vaccinations breakdown by country

# %%
by_country_totalvaccinations_max=df.groupby("country").total_vaccinations.max().reset_index(name='total_vaccinations_max')
by_country_totalvaccinations_min=df.groupby("country").total_vaccinations.min().reset_index(name='total_vaccinations_min')

# %%
# for by_country_totalvaccinations_min
#let's only keep minimum greater than 0 to exclude osme countries
by_country_totalvaccinations_min=by_country_totalvaccinations_min[by_country_totalvaccinations_min.total_vaccinations_min>0]

# %%
by_country_totalvaccinations_max.shape,by_country_totalvaccinations_min.shape
# Out:
# ((60, 2), (51, 2))

# %% [markdown]
# ### Inner Join

# %%
pd.merge(by_country_totalvaccinations_max,by_country_totalvaccinations_min, how='inner',on='country')
# Out:
#                  country  total_vaccinations_max  total_vaccinations_min
# 0              Argentina                288064.0                   700.0
# 1                Austria                169549.0                  8360.0
# 2                Bahrain                144130.0                 38965.0
# 3                Belgium                174307.0                   298.0
# 4               Bulgaria                 26119.0                  1719.0
# 5                 Canada                801238.0                   297.0
# 6                  Chile                 63047.0                   420.0
# 7                  China              15000000.0               1500000.0
# 8             Costa Rica                 29389.0                    55.0
# 9                Croatia                 64951.0                  7864.0
# 10                Cyprus                 17379.0                  3901.0
# 11               Czechia                192267.0                  1246.0
# 12               Denmark                196167.0                  6588.0
# 13               England               5526071.0                568044.0
# 14               Estonia                 25704.0                   207.0
# 15               Finland                 91260.0                  1767.0
# 16                France               1008720.0                  1000.0
# 17               Germany               1632777.0                 24256.0
# 18             Gibraltar                  8877.0                   420.0
# 19                Greece                157388.0                   386.0
# 20               Hungary                150128.0                  1094.0
# 21               Iceland                  8249.0                  4875.0
# 22               Ireland                121900.0                  1800.0
# 23           Isle of Man                  3648.0                  3558.0
# 24                Israel               3444194.0                    57.0
# 25                 Italy               1343880.0                  6983.0
# 26                Kuwait                  2500.0                  2500.0
# 27                Latvia                 19022.0                   597.0
# 28             Lithuania                 67036.0                     1.0
# 29            Luxembourg                  6897.0                  1200.0
# 30                 Malta                 17767.0                   130.0
# 31                Mexico                618768.0                  2924.0
# 32           Netherlands                135000.0                  6000.0
# 33      Northern Ireland                177026.0                  3623.0
# 34                Norway                 73844.0                     5.0
# 35                  Oman                 29548.0                  1717.0
# 36                Poland                684277.0                  2000.0
# 37              Portugal                232725.0                  4828.0
# 38               Romania                418885.0                  2066.0
# 39                Russia               1000000.0                 28500.0
# 40          Saudi Arabia                295530.0                100000.0
# 41              Scotland                385855.0                 18858.0
# 42                Serbia                163355.0                  7000.0
# 43             Singapore                 60000.0                  3400.0
# 44              Slovenia                 54839.0                  5934.0
# 45                 Spain               1165825.0                 82834.0
# 46                Sweden                146775.0                  4115.0
# 47  United Arab Emirates               2426798.0                826301.0
# 48        United Kingdom               6329968.0                667287.0
# 49         United States              20537990.0                556208.0
# 50                 Wales                241016.0                  8181.0

# %% [markdown]
# ### Left join

# %%
pd.merge(by_country_totalvaccinations_max,by_country_totalvaccinations_min, how='left',on='country')
# Out:
#                  country  total_vaccinations_max  total_vaccinations_min
# 0              Argentina                288064.0                   700.0
# 1                Austria                169549.0                  8360.0
# 2                Bahrain                144130.0                 38965.0
# 3                Belgium                174307.0                   298.0
# 4                 Brazil                537774.0                     NaN
# 5               Bulgaria                 26119.0                  1719.0
# 6                 Canada                801238.0                   297.0
# 7                  Chile                 63047.0                   420.0
# 8                  China              15000000.0               1500000.0
# 9             Costa Rica                 29389.0                    55.0
# 10               Croatia                 64951.0                  7864.0
# 11                Cyprus                 17379.0                  3901.0
# 12               Czechia                192267.0                  1246.0
# 13               Denmark                196167.0                  6588.0
# 14               Ecuador                   108.0                     NaN
# 15               England               5526071.0                568044.0
# 16               Estonia                 25704.0                   207.0
# 17               Finland                 91260.0                  1767.0
# 18                France               1008720.0                  1000.0
# 19               Germany               1632777.0                 24256.0
# 20             Gibraltar                  8877.0                   420.0
# 21                Greece                157388.0                   386.0
# 22               Hungary                150128.0                  1094.0
# 23               Iceland                  8249.0                  4875.0
# 24                 India               1582201.0                     NaN
# 25             Indonesia                132000.0                     NaN
# 26               Ireland                121900.0                  1800.0
# 27           Isle of Man                  3648.0                  3558.0
# 28                Israel               3444194.0                    57.0
# 29                 Italy               1343880.0                  6983.0
# 30                Kuwait                  2500.0                  2500.0
# 31                Latvia                 19022.0                   597.0
# 32             Lithuania                 67036.0                     1.0
# 33            Luxembourg                  6897.0                  1200.0
# 34                 Malta                 17767.0                   130.0
# 35                Mexico                618768.0                  2924.0
# 36           Netherlands                135000.0                  6000.0
# 37      Northern Ireland                177026.0                  3623.0
# 38                Norway                 73844.0                     5.0
# 39                  Oman                 29548.0                  1717.0
# 40                Panama                  5594.0                     NaN
# 41                Poland                684277.0                  2000.0
# 42              Portugal                232725.0                  4828.0
# 43               Romania                418885.0                  2066.0
# 44                Russia               1000000.0                 28500.0
# 45          Saudi Arabia                295530.0                100000.0
# 46              Scotland                385855.0                 18858.0
# 47                Serbia                163355.0                  7000.0
# 48            Seychelles                 13163.0                     NaN
# 49             Singapore                 60000.0                  3400.0
# 50              Slovakia                 92167.0                     NaN
# 51              Slovenia                 54839.0                  5934.0
# 52                 Spain               1165825.0                 82834.0
# 53                Sweden                146775.0                  4115.0
# 54           Switzerland                169783.0                     NaN
# 55                Turkey               1226883.0                     NaN
# 56  United Arab Emirates               2426798.0                826301.0
# 57        United Kingdom               6329968.0                667287.0
# 58         United States              20537990.0                556208.0
# 59                 Wales                241016.0                  8181.0

# %%
# Practice 
# see right and outer merge results look like

# %% [markdown]
# ## Joining
# <a id='Joining'> </a>
#
#  By default, .join() will attempt to do a left join on indices. If you want to join on columns like you would with merge(), then you’ll need to set the columns as indices.
#
#  Like merge(), .join() has a few parameters that give you more flexibility in your joins. However, with .join(), the list of parameters is relatively short:
#
#  - how: This has the same options as how from merge(). The difference is that it is index-based unless you also specify columns with on.
#
# When there are overlapping columns, you’ll need to specify a suffix with lsuffix, rsuffix, or both, but this example will demonstrate the more typical behavior of .join():

# %%
#set index to be country
by_country_totalvaccinations_max=by_country_totalvaccinations_max.set_index('country')
by_country_totalvaccinations_min=by_country_totalvaccinations_min.set_index('country')

# %%
by_country_totalvaccinations_max.join(by_country_totalvaccinations_min, lsuffix="_left")
# Out:
#                       total_vaccinations_max  total_vaccinations_min
# country
# Argentina                           288064.0                   700.0
# Austria                             169549.0                  8360.0
# Bahrain                             144130.0                 38965.0
# Belgium                             174307.0                   298.0
# Brazil                              537774.0                     NaN
# Bulgaria                             26119.0                  1719.0
# Canada                              801238.0                   297.0
# Chile                                63047.0                   420.0
# China                             15000000.0               1500000.0
# Costa Rica                           29389.0                    55.0
# Croatia                              64951.0                  7864.0
# Cyprus                               17379.0                  3901.0
# Czechia                             192267.0                  1246.0
# Denmark                             196167.0                  6588.0
# Ecuador                                108.0                     NaN
# England                            5526071.0                568044.0
# Estonia                              25704.0                   207.0
# Finland                              91260.0                  1767.0
# France                             1008720.0                  1000.0
# Germany                            1632777.0                 24256.0
# Gibraltar                             8877.0                   420.0
# Greece                              157388.0                   386.0
# Hungary                             150128.0                  1094.0
# Iceland                               8249.0                  4875.0
# India                              1582201.0                     NaN
# Indonesia                           132000.0                     NaN
# Ireland                             121900.0                  1800.0
# Isle of Man                           3648.0                  3558.0
# Israel                             3444194.0                    57.0
# Italy                              1343880.0                  6983.0
# Kuwait                                2500.0                  2500.0
# Latvia                               19022.0                   597.0
# Lithuania                            67036.0                     1.0
# Luxembourg                            6897.0                  1200.0
# Malta                                17767.0                   130.0
# Mexico                              618768.0                  2924.0
# Netherlands                         135000.0                  6000.0
# Northern Ireland                    177026.0                  3623.0
# Norway                               73844.0                     5.0
# Oman                                 29548.0                  1717.0
# Panama                                5594.0                     NaN
# Poland                              684277.0                  2000.0
# Portugal                            232725.0                  4828.0
# Romania                             418885.0                  2066.0
# Russia                             1000000.0                 28500.0
# Saudi Arabia                        295530.0                100000.0
# Scotland                            385855.0                 18858.0
# Serbia                              163355.0                  7000.0
# Seychelles                           13163.0                     NaN
# Singapore                            60000.0                  3400.0
# Slovakia                             92167.0                     NaN
# Slovenia                             54839.0                  5934.0
# Spain                              1165825.0                 82834.0
# Sweden                              146775.0                  4115.0
# Switzerland                         169783.0                     NaN
# Turkey                             1226883.0                     NaN
# United Arab Emirates               2426798.0                826301.0
# United Kingdom                     6329968.0                667287.0
# United States                     20537990.0                556208.0
# Wales                               241016.0                  8181.0

# %%
# Practice 
# see right and outer join results look like

# %% [markdown]
# ## Concatenation
# <a id='Concatenation'> </a>
#
# Concatenation basically glues together DataFrames. Keep in mind that dimensions should match along the axis you are concatenating on. You can use **pd.concat** and pass in a list of DataFrames to concatenate together:

# %%
by_country_totalvaccinations_max.head(1)
# Out:
#            total_vaccinations_max
# country
# Argentina                288064.0

# %%
by_country_totalvaccinations_min.head(1)
# Out:
#            total_vaccinations_min
# country
# Argentina                   700.0

# %%
pd.concat([by_country_totalvaccinations_max,by_country_totalvaccinations_min],axis=0)
# Out:
#                       total_vaccinations_max  total_vaccinations_min
# country
# Argentina                           288064.0                     NaN
# Austria                             169549.0                     NaN
# Bahrain                             144130.0                     NaN
# Belgium                             174307.0                     NaN
# Brazil                              537774.0                     NaN
# ...                                      ...                     ...
# Sweden                                   NaN                  4115.0
# United Arab Emirates                     NaN                826301.0
# United Kingdom                           NaN                667287.0
# United States                            NaN                556208.0
# Wales                                    NaN                  8181.0
#
# [111 rows x 2 columns]

# %%
#practice
# try to glue these two dataframes horizontally

# %% [markdown]
# ## Drop Columns/Rows
#
# <a id='Drop'> </a>

# %%
# you can drop a list of columns
df.drop(['USA_Flag','DownloadFrom'],axis=1)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Argentina      ARG  2020-12-29               700.0                NaN
# 1     Argentina      ARG  2020-12-30                 NaN                NaN
# 2     Argentina      ARG  2020-12-31             32013.0                NaN
# 3     Argentina      ARG  2021-01-01                 NaN                NaN
# 4     Argentina      ARG  2021-01-02                 NaN                NaN
# ...         ...      ...         ...                 ...                ...
# 1392      Wales  UNKNOWN  2021-01-18            162197.0           161932.0
# 1393      Wales  UNKNOWN  2021-01-19            176186.0           175816.0
# 1394      Wales  UNKNOWN  2021-01-20            190831.0           190435.0
# 1395      Wales  UNKNOWN  2021-01-21            212732.0           212317.0
# 1396      Wales  UNKNOWN  2021-01-22            241016.0           240547.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN             15656.0
# 2                         NaN                     NaN             15656.0
# 3                         NaN                     NaN             11070.0
# 4                         NaN                     NaN              8776.0
# ...                       ...                     ...                 ...
# 1392                    265.0                 10259.0             10123.0
# 1393                    370.0                 13989.0             10672.0
# 1394                    396.0                 14645.0             11105.0
# 1395                    415.0                 21901.0             12318.0
# 1396                    469.0                 28284.0             15148.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                            NaN
# 1                                NaN                            NaN
# 2                               0.07                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 1392                            5.14                           5.14
# 1393                            5.59                           5.58
# 1394                            6.05                           6.04
# 1395                            6.75                           6.73
# 1396                            7.64                           7.63
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                           346.0
# 2                                     NaN                           346.0
# 3                                     NaN                           245.0
# 4                                     NaN                           194.0
# ...                                   ...                             ...
# 1392                                 0.01                          3211.0
# 1393                                 0.01                          3385.0
# 1394                                 0.01                          3522.0
# 1395                                 0.01                          3907.0
# 1396                                 0.01                          4804.0
#
#                                  vaccines                       source_name  \
# 0                               Sputnik V                Ministry of Health
# 1                               Sputnik V                Ministry of Health
# 2                               Sputnik V                Ministry of Health
# 3                               Sputnik V                Ministry of Health
# 4                               Sputnik V                Ministry of Health
# ...                                   ...                               ...
# 1392  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1393  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1394  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1395  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1396  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                 ...
# 1392  https://coronavirus.data.gov.uk/details/health...
# 1393  https://coronavirus.data.gov.uk/details/health...
# 1394  https://coronavirus.data.gov.uk/details/health...
# 1395  https://coronavirus.data.gov.uk/details/health...
# 1396  https://coronavirus.data.gov.uk/details/health...
#
# [1397 rows x 15 columns]

# %%
#Practice
#Can you drop first row in the dataset?

# %% [markdown]
# ## Rename Column
#
# <a id='Rename'> </a>

# %%
df.rename(columns={'iso_code':'Country ISO Code'})
# Out:
#         country Country ISO Code        date  total_vaccinations  \
# 0     Argentina              ARG  2020-12-29               700.0
# 1     Argentina              ARG  2020-12-30                 NaN
# 2     Argentina              ARG  2020-12-31             32013.0
# 3     Argentina              ARG  2021-01-01                 NaN
# 4     Argentina              ARG  2021-01-02                 NaN
# ...         ...              ...         ...                 ...
# 1392      Wales          UNKNOWN  2021-01-18            162197.0
# 1393      Wales          UNKNOWN  2021-01-19            176186.0
# 1394      Wales          UNKNOWN  2021-01-20            190831.0
# 1395      Wales          UNKNOWN  2021-01-21            212732.0
# 1396      Wales          UNKNOWN  2021-01-22            241016.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                   NaN                      NaN                     NaN
# 1                   NaN                      NaN                     NaN
# 2                   NaN                      NaN                     NaN
# 3                   NaN                      NaN                     NaN
# 4                   NaN                      NaN                     NaN
# ...                 ...                      ...                     ...
# 1392           161932.0                    265.0                 10259.0
# 1393           175816.0                    370.0                 13989.0
# 1394           190435.0                    396.0                 14645.0
# 1395           212317.0                    415.0                 21901.0
# 1396           240547.0                    469.0                 28284.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 0                    NaN                            0.00
# 1                15656.0                             NaN
# 2                15656.0                            0.07
# 3                11070.0                             NaN
# 4                 8776.0                             NaN
# ...                  ...                             ...
# 1392             10123.0                            5.14
# 1393             10672.0                            5.59
# 1394             11105.0                            6.05
# 1395             12318.0                            6.75
# 1396             15148.0                            7.64
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# ...                             ...                                  ...
# 1392                           5.14                                 0.01
# 1393                           5.58                                 0.01
# 1394                           6.04                                 0.01
# 1395                           6.73                                 0.01
# 1396                           7.63                                 0.01
#
#       daily_vaccinations_per_million                             vaccines  \
# 0                                NaN                            Sputnik V
# 1                              346.0                            Sputnik V
# 2                              346.0                            Sputnik V
# 3                              245.0                            Sputnik V
# 4                              194.0                            Sputnik V
# ...                              ...                                  ...
# 1392                          3211.0  Oxford/AstraZeneca, Pfizer/BioNTech
# 1393                          3385.0  Oxford/AstraZeneca, Pfizer/BioNTech
# 1394                          3522.0  Oxford/AstraZeneca, Pfizer/BioNTech
# 1395                          3907.0  Oxford/AstraZeneca, Pfizer/BioNTech
# 1396                          4804.0  Oxford/AstraZeneca, Pfizer/BioNTech
#
#                            source_name  \
# 0                   Ministry of Health
# 1                   Ministry of Health
# 2                   Ministry of Health
# 3                   Ministry of Health
# 4                   Ministry of Health
# ...                                ...
# 1392  Government of the United Kingdom
# 1393  Government of the United Kingdom
# 1394  Government of the United Kingdom
# 1395  Government of the United Kingdom
# 1396  Government of the United Kingdom
#
#                                          source_website DownloadFrom  USA_Flag
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...       Kaggle       NaN
# ...                                                 ...          ...       ...
# 1392  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1393  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1394  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1395  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
# 1396  https://coronavirus.data.gov.uk/details/health...       Kaggle       NaN
#
# [1397 rows x 17 columns]

# %% [markdown]
# ## Pivot Table
#
# <a id='Pivot'> </a>
#
#
# pivot_table requires a
# - data
# - and an index parameter
#
#
# data is the Pandas dataframe you pass to the function
# index is the feature that allows you to group your data. The index feature will appear as an index in the resultant table.
#
# The values shown in the table are the result of the summarization that aggfunc applies to the feature data. aggfunc is an aggregate function that pivot_table applies to your grouped data.

# %%
df.pivot_table(values='people_vaccinated',index=['date'])
# Out:
#             people_vaccinated
# date
# 2020-12-13       1.022067e+04
# 2020-12-14       2.970000e+02
# 2020-12-15       5.098877e+05
# 2020-12-16       3.683000e+03
# 2020-12-17       7.201000e+03
# 2020-12-18       1.061500e+04
# 2020-12-19       5.975500e+03
# 2020-12-20       2.390270e+05
# 2020-12-21       2.214350e+05
# 2020-12-22       4.947967e+04
# 2020-12-23       2.422184e+05
# 2020-12-24       5.961340e+04
# 2020-12-25       6.767100e+04
# 2020-12-26       4.644158e+05
# 2020-12-27       1.482894e+05
# 2020-12-28       1.349417e+05
# 2020-12-29       5.047326e+04
# 2020-12-30       1.765702e+05
# 2020-12-31       3.310680e+05
# 2021-01-01       1.171053e+05
# 2021-01-02       4.837113e+05
# 2021-01-03       2.168152e+05
# 2021-01-04       2.812289e+05
# 2021-01-05       2.880214e+05
# 2021-01-06       3.306785e+05
# 2021-01-07       3.419937e+05
# 2021-01-08       3.830151e+05
# 2021-01-09       5.129093e+05
# 2021-01-10       3.135329e+05
# 2021-01-11       5.471522e+05
# 2021-01-12       5.955998e+05
# 2021-01-13       6.310228e+05
# 2021-01-14       6.776738e+05
# 2021-01-15       7.059530e+05
# 2021-01-16       5.211483e+05
# 2021-01-17       4.965337e+05
# 2021-01-18       5.416450e+05
# 2021-01-19       8.397405e+05
# 2021-01-20       1.168006e+06
# 2021-01-21       9.592511e+05
# 2021-01-22       9.761299e+05
# 2021-01-23       1.346885e+06

# %% [markdown]
# Using multiple features as indexes is fine, but using some features as columns will help you to intuitively understand the relationship between them. Also, the resultant table can always be better viewed by incorporating the columns parameter of the pivot_table.
#
# This columns parameter is optional and displays the values horizontally on the top of the resultant table.
#
# Both columns and the index parameters are optional, but using them effectively will help you to intuitively understand the relationship between the features.

# %%
df.pivot_table(values='people_vaccinated',index=['date'],columns=['country'])
# Out:
# country     Argentina   Austria   Bahrain   Belgium    Brazil  Bulgaria  \
# date
# 2020-12-13        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-14        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-15        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-16        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-17        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-18        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-19        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-20        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-21        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-22        NaN       NaN       NaN       NaN       NaN       NaN
# 2020-12-23        NaN       NaN   38965.0       NaN       NaN       NaN
# 2020-12-24        NaN       NaN   50071.0       NaN       NaN       NaN
# 2020-12-25        NaN       NaN   50543.0       NaN       NaN       NaN
# 2020-12-26        NaN       NaN   51556.0       NaN       NaN       NaN
# 2020-12-27        NaN       NaN   53614.0       NaN       NaN       NaN
# 2020-12-28        NaN       NaN   55014.0     298.0       NaN       NaN
# 2020-12-29        NaN       NaN   56041.0     299.0       NaN    1719.0
# 2020-12-30        NaN       NaN   57317.0     766.0       NaN    4608.0
# 2020-12-31        NaN       NaN   58643.0     775.0       NaN       NaN
# 2021-01-01        NaN       NaN   59351.0     784.0       NaN    4739.0
# 2021-01-02        NaN       NaN   60097.0       NaN       NaN       NaN
# 2021-01-03        NaN       NaN   60689.0       NaN       NaN       NaN
# 2021-01-04        NaN       NaN   61612.0     785.0       NaN       NaN
# 2021-01-05        NaN    8360.0   63893.0    2283.0       NaN    5448.0
# 2021-01-06        NaN       NaN   68472.0    5916.0       NaN    7913.0
# 2021-01-07        NaN   15095.0   72239.0   13757.0       NaN   11117.0
# 2021-01-08        NaN   30150.0   78291.0   22723.0       NaN   13355.0
# 2021-01-09        NaN   31525.0   84157.0   25830.0       NaN   13473.0
# 2021-01-10        NaN   31885.0   89250.0   26223.0       NaN       NaN
# 2021-01-11        NaN   38545.0   92598.0   31573.0       NaN   14161.0
# 2021-01-12        NaN   52925.0   97776.0   46271.0       NaN   15780.0
# 2021-01-13        NaN   63280.0  101363.0   65822.0       NaN   17038.0
# 2021-01-14        NaN   74100.0  109566.0   85996.0       NaN   17686.0
# 2021-01-15        NaN   84380.0  122819.0  106885.0       NaN   18126.0
# 2021-01-16        NaN   87195.0  137159.0  111552.0       0.0   18332.0
# 2021-01-17        NaN  102790.0  141563.0  114298.0     112.0   18453.0
# 2021-01-18        NaN       NaN  142831.0  123408.0    1109.0   18524.0
# 2021-01-19        NaN  140232.0  143596.0  137068.0   11470.0   19058.0
# 2021-01-20   243539.0  150703.0  144130.0  151080.0   28543.0   19834.0
# 2021-01-21   249372.0  161965.0       NaN  163410.0  136519.0   20719.0
# 2021-01-22   254456.0  166956.0       NaN  173899.0  245877.0   21496.0
# 2021-01-23   258876.0  169549.0       NaN       NaN  537774.0   21509.0
#
# country       Canada    Chile       China  Costa Rica  ...  Slovakia  \
# date                                                   ...
# 2020-12-13       NaN      NaN         NaN         NaN  ...       NaN
# 2020-12-14     297.0      NaN         NaN         NaN  ...       NaN
# 2020-12-15    1163.0      NaN   1500000.0         NaN  ...       NaN
# 2020-12-16    3683.0      NaN         NaN         NaN  ...       NaN
# 2020-12-17    7201.0      NaN         NaN         NaN  ...       NaN
# 2020-12-18   10615.0      NaN         NaN         NaN  ...       NaN
# 2020-12-19   11894.0      NaN         NaN         NaN  ...       NaN
# 2020-12-20   14492.0      NaN         NaN         NaN  ...       NaN
# 2020-12-21   20866.0      NaN         NaN         NaN  ...       NaN
# 2020-12-22   26287.0      NaN         NaN         NaN  ...       NaN
# 2020-12-23   35089.0      NaN         NaN         NaN  ...       NaN
# 2020-12-24   45398.0    420.0         NaN         NaN  ...       NaN
# 2020-12-25   45700.0   5191.0         NaN         NaN  ...       NaN
# 2020-12-26   48719.0   8335.0         NaN         NaN  ...       NaN
# 2020-12-27   52280.0   8646.0         NaN         NaN  ...       NaN
# 2020-12-28   59449.0      NaN         NaN         NaN  ...       NaN
# 2020-12-29   70749.0      NaN         NaN         NaN  ...       NaN
# 2020-12-30   79482.0      NaN         NaN         NaN  ...       NaN
# 2020-12-31   95832.0      NaN   4500000.0         NaN  ...       NaN
# 2021-01-01  104347.0      NaN         NaN         NaN  ...       NaN
# 2021-01-02  112425.0      NaN         NaN         NaN  ...       NaN
# 2021-01-03  117727.0      NaN         NaN         NaN  ...       NaN
# 2021-01-04  136759.0   9051.0         NaN         NaN  ...       0.0
# 2021-01-05  155527.0  10494.0         NaN         NaN  ...     425.0
# 2021-01-06  183690.0  10699.0         NaN         NaN  ...    6618.0
# 2021-01-07  219464.0      NaN         NaN         NaN  ...   13631.0
# 2021-01-08  261234.0      NaN         NaN         NaN  ...   20548.0
# 2021-01-09  297352.0      NaN   9000000.0         NaN  ...   22281.0
# 2021-01-10  321049.0      NaN         NaN         NaN  ...   25326.0
# 2021-01-11  360160.0      NaN         NaN         NaN  ...   29221.0
# 2021-01-12  388493.0      NaN         NaN         NaN  ...   39735.0
# 2021-01-13  419209.0  11743.0  10000000.0         NaN  ...   46243.0
# 2021-01-14  459492.0  12787.0         NaN         NaN  ...   53425.0
# 2021-01-15  507687.0  13755.0         NaN     24804.0  ...   60753.0
# 2021-01-16  543291.0  13766.0         NaN         NaN  ...   61961.0
# 2021-01-17  570742.0  13781.0         NaN         NaN  ...   62015.0
# 2021-01-18  614666.0  24025.0         NaN     29257.0  ...   70416.0
# 2021-01-19  651139.0  42564.0         NaN         NaN  ...   77005.0
# 2021-01-20  696242.0  45676.0  15000000.0         NaN  ...   83438.0
# 2021-01-21  738864.0  54458.0         NaN         NaN  ...   89635.0
# 2021-01-22  776606.0  54683.0         NaN         NaN  ...       NaN
# 2021-01-23  801238.0      NaN         NaN         NaN  ...       NaN
#
# country     Slovenia      Spain    Sweden  Switzerland     Turkey  \
# date
# 2020-12-13       NaN        NaN       NaN          NaN        NaN
# 2020-12-14       NaN        NaN       NaN          NaN        NaN
# 2020-12-15       NaN        NaN       NaN          NaN        NaN
# 2020-12-16       NaN        NaN       NaN          NaN        NaN
# 2020-12-17       NaN        NaN       NaN          NaN        NaN
# 2020-12-18       NaN        NaN       NaN          NaN        NaN
# 2020-12-19       NaN        NaN       NaN          NaN        NaN
# 2020-12-20       NaN        NaN       NaN          NaN        NaN
# 2020-12-21       NaN        NaN       NaN          NaN        NaN
# 2020-12-22       NaN        NaN       NaN          NaN        NaN
# 2020-12-23       NaN        NaN       NaN          0.0        NaN
# 2020-12-24       NaN        NaN       NaN          NaN        NaN
# 2020-12-25       NaN        NaN       NaN          NaN        NaN
# 2020-12-26       NaN        NaN       NaN          NaN        NaN
# 2020-12-27       NaN        NaN    4115.0          NaN        NaN
# 2020-12-28       NaN        NaN       NaN          NaN        NaN
# 2020-12-29       NaN        NaN       NaN          NaN        NaN
# 2020-12-30       NaN        NaN       NaN          NaN        NaN
# 2020-12-31       NaN        NaN       NaN          NaN        NaN
# 2021-01-01       NaN        NaN       NaN          NaN        NaN
# 2021-01-02       NaN        NaN       NaN          NaN        NaN
# 2021-01-03    5934.0        NaN   31129.0          NaN        NaN
# 2021-01-04    7204.0    82834.0       NaN          NaN        NaN
# 2021-01-05    8901.0   139339.0       NaN          NaN        NaN
# 2021-01-06   12265.0        NaN       NaN          NaN        NaN
# 2021-01-07   16339.0   207323.0       NaN          NaN        NaN
# 2021-01-08   19523.0   277976.0       NaN          NaN        NaN
# 2021-01-09   19930.0        NaN       NaN          NaN        NaN
# 2021-01-10   20546.0        NaN   79466.0          NaN        NaN
# 2021-01-11   22484.0   406091.0       NaN          NaN        NaN
# 2021-01-12   24462.0   488122.0       NaN          NaN        NaN
# 2021-01-13   29561.0   581638.0       NaN          NaN        0.0
# 2021-01-14   35159.0   676186.0       NaN      66000.0   279452.0
# 2021-01-15   40778.0   768950.0       NaN          NaN   616652.0
# 2021-01-16   41439.0        NaN       NaN          NaN   676903.0
# 2021-01-17   42035.0        NaN  146775.0          NaN   706451.0
# 2021-01-18   43081.0   895627.0       NaN          NaN   832412.0
# 2021-01-19   43869.0   956756.0       NaN     110000.0   950635.0
# 2021-01-20   46467.0  1010295.0       NaN          NaN  1052493.0
# 2021-01-21   46467.0  1054245.0       NaN     169783.0  1120258.0
# 2021-01-22   48170.0  1097369.0       NaN          NaN  1202212.0
# 2021-01-23       NaN        NaN       NaN          NaN  1226883.0
#
# country     United Arab Emirates  United Kingdom  United States     Wales
# date
# 2020-12-13                   NaN             NaN            NaN    8181.0
# 2020-12-14                   NaN             NaN            NaN       NaN
# 2020-12-15                   NaN             NaN            NaN       NaN
# 2020-12-16                   NaN             NaN            NaN       NaN
# 2020-12-17                   NaN             NaN            NaN       NaN
# 2020-12-18                   NaN             NaN            NaN       NaN
# 2020-12-19                   NaN             NaN            NaN       NaN
# 2020-12-20                   NaN        667287.0       556208.0   23567.0
# 2020-12-21                   NaN             NaN       614117.0       NaN
# 2020-12-22                   NaN             NaN            NaN       NaN
# 2020-12-23                   NaN             NaN      1008025.0       NaN
# 2020-12-24                   NaN             NaN            NaN       NaN
# 2020-12-25                   NaN             NaN            NaN       NaN
# 2020-12-26                   NaN             NaN      1944585.0       NaN
# 2020-12-27                   NaN        992246.0            NaN   35910.0
# 2020-12-28                   NaN             NaN      2127143.0       NaN
# 2020-12-29                   NaN             NaN            NaN       NaN
# 2020-12-30                   NaN             NaN      2794588.0       NaN
# 2020-12-31                   NaN             NaN            NaN       NaN
# 2021-01-01                   NaN             NaN            NaN       NaN
# 2021-01-02                   NaN             NaN      4225756.0       NaN
# 2021-01-03                   NaN       1360036.0            NaN   49851.0
# 2021-01-04                   NaN             NaN      4563260.0       NaN
# 2021-01-05                   NaN             NaN      4836469.0       NaN
# 2021-01-06                   NaN             NaN      5306797.0       NaN
# 2021-01-07                   NaN             NaN      5919418.0       NaN
# 2021-01-08                   NaN             NaN      6688231.0       NaN
# 2021-01-09                   NaN             NaN            NaN       NaN
# 2021-01-10              836568.0       2286572.0            NaN   86039.0
# 2021-01-11              917251.0       2431648.0      8987322.0   91239.0
# 2021-01-12             1025652.0       2639309.0      9327138.0  101371.0
# 2021-01-13             1144580.0       2918252.0            NaN  112973.0
# 2021-01-14             1277833.0       3234946.0      9690757.0  126375.0
# 2021-01-15             1415987.0       3559179.0     10595866.0       NaN
# 2021-01-16             1547926.0       3837094.0            NaN       NaN
# 2021-01-17             1632778.0       4062501.0            NaN  151737.0
# 2021-01-18             1721521.0       4266577.0            NaN  161932.0
# 2021-01-19             1815367.0       4609740.0     13595803.0  175816.0
# 2021-01-20             1911150.0       4973248.0     14270441.0  190435.0
# 2021-01-21             1996069.0       5383103.0     15053257.0  212317.0
# 2021-01-22             2089078.0       5861351.0     16243093.0  240547.0
# 2021-01-23             2176798.0             NaN     17390345.0       NaN
#
# [42 rows x 60 columns]

# %%
# Pratice 
# Get mean of the Total number of vaccinations by Vaccines used in the country

# %% [markdown]
# ## Optional: Data input from HTML
# <a id='HTML'> </a>
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %%
### HTML Input

#Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

df = pd.read_html('https://en.wikipedia.org/wiki/Pythonidae')

# %%
len(df)
# Out:
# 8

# %%
#Now, we get a list of 8 tables. If we go to the Wikipedia page, we can see that the first table is the one to the right. 
df[1]
# Out:
#                                            Pythonidae  \
# 0                                                 NaN
# 1                      Indian python (Python molurus)
# 2                           Scientific classification
# 3                                            Kingdom:
# 4                                             Phylum:
# 5                                              Class:
# 6                                              Order:
# 7                                           Suborder:
# 8                                        Superfamily:
# 9                                             Family:
# 10                                           Synonyms
# 11  Pythonoidia - Fitzinger, 1826 Pythonoidei - Ei...
#
#                                          Pythonidae.1
# 0                                                 NaN
# 1                      Indian python (Python molurus)
# 2                           Scientific classification
# 3                                            Animalia
# 4                                            Chordata
# 5                                            Reptilia
# 6                                            Squamata
# 7                                           Serpentes
# 8                                         Pythonoidea
# 9                           PythonidaeFitzinger, 1826
# 10                                           Synonyms
# 11  Pythonoidia - Fitzinger, 1826 Pythonoidei - Ei...

# %%
df[2]
# Out:
#         Genus[2]                                    Taxon author[2]  \
# 0      Antaresia                           Wells & Wellington, 1984
# 1    Apodora[13]                                        Kluge, 1993
# 2      Aspidites                                       Peters, 1877
# 3   Bothrochilus                                    Fitzinger, 1843
# 4     Leiopython                                     Hubrecht, 1879
# 5         Liasis                                         Gray, 1842
# 6   Malayopython                                     Reynolds, 2014
# 7        Morelia                                         Gray, 1842
# 8        Nawaran  Donnellan, Brennan, Lemmon, Moriarty Lemmon, Z...
# 9      Python[b]                                       Daudin, 1803
# 10       Simalia                                         Gray, 1849
#
#     Species[2]  Subsp.[a][2]                         Common name  \
# 0            4             2                  Children's pythons
# 1            1             0                 Papuan olive python
# 2            2             0                      Shield pythons
# 3            7             0                White-lipped pythons
# 4            2             0                                 NaN
# 5            3             5                       Water pythons
# 6            2             3       Reticulated and Timor pythons
# 7            8             6                        Tree pythons
# 8            4             0                     Oenpelli python
# 9           10             2                      "True" pythons
# 10           6             0  Amethystine python species complex
#
#                                   Geographic range[1]
# 0              Australia in arid and tropical regions
# 1                                    Papua New Guinea
# 2        Australia except in the south of the country
# 3   Most of New Guinea (below 1,200 metres (3,900 ...
# 4                                    Papua New Guinea
# 5   Indonesia in the Lesser Sunda Islands, east th...
# 6                                 From India to Timor
# 7   From Indonesia in the Maluku Islands, east thr...
# 8                        Northern Territory,Australia
# 9   Africa in the tropics south of the Sahara (not...
# 10  Found in Indonesia (Including the islands of H...

# %% [markdown]
# ## Optional: Data input from SQL
# <a id='SQL'> </a>
#
# The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

df[1].to_sql('data', engine)

sql_df = pd.read_sql('data',con=engine)

sql_df
# Out:
#     index                                         Pythonidae  \
# 0       0                                               None
# 1       1                     Indian python (Python molurus)
# 2       2                          Scientific classification
# 3       3                                           Kingdom:
# 4       4                                            Phylum:
# 5       5                                             Class:
# 6       6                                             Order:
# 7       7                                          Suborder:
# 8       8                                       Superfamily:
# 9       9                                            Family:
# 10     10                                           Synonyms
# 11     11  Pythonoidia - Fitzinger, 1826 Pythonoidei - Ei...
#
#                                          Pythonidae.1
# 0                                                None
# 1                      Indian python (Python molurus)
# 2                           Scientific classification
# 3                                            Animalia
# 4                                            Chordata
# 5                                            Reptilia
# 6                                            Squamata
# 7                                           Serpentes
# 8                                         Pythonoidea
# 9                           PythonidaeFitzinger, 1826
# 10                                           Synonyms
# 11  Pythonoidia - Fitzinger, 1826 Pythonoidei - Ei...
